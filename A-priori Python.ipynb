# %% [markdown]
# ### Cell 1

# %%
import pandas as pd

df = pd.read_csv('Dataset_B.csv')
df['item_count'] = 1                #put 1 for each item, making it countable for item counts
df.dtypes                           #check datatypes for all columns
# Out:
# Member_number       int64
# Date               object
# itemDescription    object
# item_count          int64
# dtype: object

# %% [markdown]
# ### Cell 2

# %%
df['Member_number'] = df['Member_number'].astype(str)   #convert member number to string as we do not wish to perform any mathematical computation. Only identification
df.dtypes                                               #check if data type has been changed
# Out:
# Member_number      object
# Date               object
# itemDescription    object
# item_count          int64
# dtype: object

# %% [markdown]
# ### Cell 3

# %%
df.describe(include='all')  #statistical summary of the whole dataframe
# Out:
#        Member_number        Date itemDescription  item_count
# count          19415       19415           19415     19415.0
# unique          3814         728             164         NaN
# top             3308  28-08-2014      whole milk         NaN
# freq              19          54             957         NaN
# mean             NaN         NaN             NaN         1.0
# std              NaN         NaN             NaN         0.0
# min              NaN         NaN             NaN         1.0
# 25%              NaN         NaN             NaN         1.0
# 50%              NaN         NaN             NaN         1.0
# 75%              NaN         NaN             NaN         1.0
# max              NaN         NaN             NaN         1.0

# %% [markdown]
# ### Cell 4

# %%
df_table = pd.DataFrame(df.groupby('itemDescription')['item_count'].sum().sort_values(ascending=False).reset_index())   #create new dataframe with item counts sorted in descending order
df_table.head().style.background_gradient(cmap='Greens')                                                                #view first 5 rows of dataframe
# Out:
# <style type="text/css">
# #T_25db8_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_25db8_row1_col1 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_25db8_row2_col1 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_25db8_row3_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_25db8_row4_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_25db8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >itemDescription</th>
#       <th class="col_heading level0 col1" >item_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25db8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25db8_row0_col0" class="data row0 col0" >whole milk</td>
#       <td id="T_25db8_row0_col1" class="data row0 col1" >957</td>
#     </tr>
#     <tr>
#       <th id="T_25db8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25db8_row1_col0" class="data row1 col0" >rolls/buns</td>
#       <td id="T_25db8_row1_col1" class="data row1 col1" >901</td>
#     </tr>
#     <tr>
#       <th id="T_25db8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25db8_row2_col0" class="data row2 col0" >soda</td>
#       <td id="T_25db8_row2_col1" class="data row2 col1" >863</td>
#     </tr>
#     <tr>
#       <th id="T_25db8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25db8_row3_col0" class="data row3 col0" >yogurt</td>
#       <td id="T_25db8_row3_col1" class="data row3 col1" >774</td>
#     </tr>
#     <tr>
#       <th id="T_25db8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25db8_row4_col0" class="data row4 col0" >other vegetables</td>
#       <td id="T_25db8_row4_col1" class="data row4 col1" >752</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Cell 5

# %%
import plotly.express as px         #import library for visualization

df_table['all'] = 'Top 50 items'    #ensure whole dataframe has the same origin in the treemap

#creating a treemap for the top 50 items bought
fig = px.treemap(df_table.head(50), path=['all', 'itemDescription'], values='item_count', color=df_table['item_count'].head(50), hover_data=['itemDescription'], color_continuous_scale='Greens')
fig.show()

# %% [markdown]
# ### Cell 6

# %%
item_dict = dict()                                  #dictionary to store the grouped data
                                                    #loop through each row of the dataframe
for i in df.values:                                 #store each row in a list format
    i = list(i)                                     #check if (i[0]=Member_number) is already present in the dictionary  
    if i[0] in item_dict.keys():                    #check if (i[1]=Date) is already present under the Member_number
        if i[1] in item_dict[i[0]]:                 #if i[0] and i[1] are both present, append the items bought on that day
            item_dict[i[0]][i[1]].append(i[2])      
        else:
            item_dict[i[0]].update({i[1]:[i[2]]})   #if i[1] is not present in in i[0], update the dictionary with the date and item bought
    else:
        item_dict[i[0]] = {i[1]:[i[2]]}             #if Member_number is not present in the dictionary, create a new entry with Member_number, Date and item_bought

item_dict
# Out:
# {'3562': {'18-03-2015': ['salty snack'],
#   '13-08-2015': ['whole milk', 'soda', 'canned beer', 'hygiene articles'],
#   '30-12-2015': ['shopping bags', 'rolls/buns'],
#   '11-09-2014': ['white wine'],
#   '17-12-2014': ['male cosmetics', 'newspapers']},
#  '3145': {'16-11-2015': ['cake bar'],
#   '15-08-2014': ['whole milk'],
#   '16-08-2014': ['candy']},
#  '3595': {'17-12-2015': ['whole milk'],
#   '06-08-2015': ['other vegetables'],
#   '15-10-2015': ['zwieback'],
#   '21-03-2015': ['cream cheese ', 'waffles'],
#   '06-01-2014': ['canned beer', 'bottled water', 'waffles'],
#   '17-01-2014': ['curd']},
#  '4934': {'17-03-2015': ['other vegetables'], '13-10-2014': ['bottled beer']},
#  '3386': {'03-02-2015': ['yogurt'],
#   '07-08-2014': ['baking powder'],
#   '18-03-2014': ['pasta'],
#   '10-05-2014': ['soda']},
#  '4125': {'21-03-2015': ['yogurt'],
#   '20-03-2014': ['brown bread', 'candy'],
#   '03-06-2014': ['rolls/buns'],
#   '21-09-2014': ['pastry', 'pet care']},
#  '2570': {'19-03-2015': ['roll products '],
#   '24-08-2015': ['oil'],
#   '19-06-2014': ['root vegetables'],
#   '29-07-2014': ['bottled water', 'long life bakery product'],
#   '25-02-2014': ['roll products ']},
#  '3613': {'05-10-2015': ['other vegetables'],
#   '05-06-2015': ['root vegetables', 'roll products '],
#   '25-01-2014': ['shopping bags'],
#   '20-10-2014': ['bottled water', 'pastry', 'flour']},
#  '3292': {'31-07-2015': ['dessert'], '08-08-2014': ['red/blush wine']},
#  '1409': {'02-07-2015': ['snack products'],
#   '17-02-2015': ['whole milk'],
#   '28-07-2015': ['tropical fruit']},
#  '3315': {'19-11-2015': ['candy'],
#   '12-09-2015': ['onions', 'coffee'],
#   '27-12-2014': ['chewing gum', 'yogurt'],
#   '25-09-2014': ['canned beer'],
#   '21-01-2014': ['whole milk']},
#  '3486': {'29-01-2015': ['yogurt'],
#   '23-12-2015': ['pip fruit', 'spread cheese'],
#   '27-01-2014': ['whipped/sour cream'],
#   '12-09-2014': ['candy']},
#  '1256': {'02-08-2015': ['coffee'],
#   '29-08-2015': ['butter', 'oil'],
#   '14-10-2014': ['other vegetables'],
#   '07-11-2014': ['domestic eggs'],
#   '17-06-2014': ['tea', 'coffee']},
#  '2523': {'04-07-2015': ['other vegetables'],
#   '12-01-2015': ['semi-finished bread', 'napkins'],
#   '12-02-2015': ['margarine', 'soda'],
#   '11-10-2014': ['rolls/buns', 'shopping bags'],
#   '04-04-2015': ['yogurt']},
#  '1432': {'04-08-2015': ['grapes'],
#   '18-02-2014': ['pip fruit', 'specialty bar'],
#   '18-09-2014': ['long life bakery product', 'pickled vegetables'],
#   '12-03-2014': ['bottled beer']},
#  '4819': {'01-10-2015': ['rolls/buns'],
#   '20-09-2015': ['soda', 'bottled water'],
#   '20-08-2014': ['pip fruit'],
#   '23-04-2014': ['domestic eggs', 'sugar']},
#  '4455': {'30-06-2015': ['whole milk'],
#   '24-10-2015': ['curd'],
#   '18-06-2014': ['canned fish'],
#   '09-10-2014': ['rolls/buns'],
#   '26-08-2014': ['soda']},
#  '3467': {'27-11-2015': ['citrus fruit'],
#   '20-10-2014': ['pastry', 'candy'],
#   '08-11-2014': ['citrus fruit'],
#   '07-04-2014': ['shopping bags']},
#  '1991': {'22-10-2015': ['nuts/prunes'],
#   '10-02-2015': ['specialty bar', 'soda'],
#   '09-12-2015': ['other vegetables'],
#   '14-07-2014': ['yogurt'],
#   '25-12-2014': ['flour', 'fruit/vegetable juice', 'fruit/vegetable juice'],
#   '13-05-2014': ['newspapers', 'long life bakery product'],
#   '12-03-2014': ['coffee'],
#   '31-10-2014': ['butter', 'frozen fish'],
#   '23-12-2014': ['bottled beer', 'soap']},
#  '4862': {'15-05-2015': ['soft cheese'],
#   '12-10-2014': ['white bread'],
#   '08-06-2014': ['tropical fruit',
#    'whipped/sour cream',
#    'Instant food products'],
#   '26-04-2014': ['whole milk', 'flower (seeds)'],
#   '18-07-2014': ['yogurt', 'soda']},
#  '3225': {'25-02-2015': ['frozen vegetables'],
#   '12-06-2015': ['whole milk', 'soda'],
#   '12-12-2015': ['other vegetables'],
#   '25-06-2014': ['ice cream'],
#   '19-09-2014': ['yogurt', 'whipped/sour cream', 'napkins'],
#   '23-07-2014': ['soda'],
#   '15-07-2014': ['bottled beer', 'whipped/sour cream']},
#  '3296': {'27-06-2015': ['other vegetables'],
#   '02-03-2015': ['root vegetables', 'detergent'],
#   '06-06-2015': ['specialty bar', 'yogurt'],
#   '22-05-2015': ['packaged fruit/vegetables', 'baking powder']},
#  '4179': {'21-03-2015': ['cat food'],
#   '06-03-2015': ['pickled vegetables', 'pastry'],
#   '03-08-2014': ['other vegetables']},
#  '4641': {'06-07-2015': ['pip fruit'],
#   '11-05-2014': ['whole milk'],
#   '16-03-2014': ['specialty chocolate'],
#   '05-09-2014': ['cereals']},
#  '3411': {'19-06-2015': ['margarine'],
#   '30-11-2014': ['margarine'],
#   '02-05-2014': ['dessert'],
#   '03-12-2014': ['whole milk', 'roll products ']},
#  '1932': {'15-03-2015': ['UHT-milk'],
#   '07-09-2015': ['pip fruit'],
#   '27-06-2015': ['tropical fruit'],
#   '02-06-2014': ['onions'],
#   '06-07-2014': ['bottled beer', 'other vegetables', 'oil'],
#   '02-08-2014': ['cat food'],
#   '19-06-2014': ['fruit/vegetable juice', 'bottled water']},
#  '1324': {'10-04-2015': ['whole milk'],
#   '27-12-2015': ['salt', 'curd'],
#   '10-07-2015': ['white wine', 'rolls/buns']},
#  '4787': {'12-08-2015': ['whole milk'],
#   '17-05-2015': ['UHT-milk'],
#   '25-05-2015': ['cat food'],
#   '18-12-2014': ['cling film/bags'],
#   '27-08-2014': ['fruit/vegetable juice', 'candles']},
#  '1497': {'10-10-2015': ['margarine'],
#   '18-04-2015': ['liquor (appetizer)', 'coffee'],
#   '26-05-2014': ['tea']},
#  '3666': {'12-04-2015': ['specialty chocolate'],
#   '16-02-2015': ['other vegetables', 'whole milk'],
#   '12-04-2014': ['yogurt', 'cream cheese '],
#   '14-06-2014': ['bottled water'],
#   '15-10-2014': ['waffles']},
#  '4338': {'06-09-2015': ['onions'],
#   '27-08-2015': ['ham', 'flour'],
#   '24-03-2015': ['pickled vegetables'],
#   '24-06-2015': ['white bread'],
#   '25-10-2014': ['candy'],
#   '14-04-2014': ['pudding powder'],
#   '07-07-2014': ['salty snack', 'waffles', 'frozen dessert'],
#   '09-10-2014': ['pip fruit'],
#   '21-04-2014': ['rice']},
#  '4159': {'28-12-2015': ['tropical fruit'],
#   '11-07-2014': ['cat food'],
#   '29-05-2014': ['dishes']},
#  '4558': {'03-04-2015': ['dental care'],
#   '05-04-2015': ['tropical fruit'],
#   '27-08-2014': ['UHT-milk']},
#  '4680': {'27-08-2015': ['pip fruit'],
#   '22-08-2015': ['yogurt'],
#   '06-04-2014': ['waffles', 'soda'],
#   '23-01-2014': ['white wine', 'chocolate marshmallow']},
#  '4303': {'25-09-2015': ['semi-finished bread'],
#   '22-02-2015': ['tropical fruit', 'butter'],
#   '23-08-2015': ['soups', 'shopping bags'],
#   '08-04-2015': ['other vegetables', 'cream cheese '],
#   '24-10-2014': ['butter'],
#   '17-01-2014': ['shopping bags', 'instant coffee'],
#   '28-11-2014': ['specialty bar']},
#  '4595': {'07-08-2015': ['frozen meals'],
#   '11-06-2014': ['white bread', 'salty snack']},
#  '2600': {'16-12-2015': ['other vegetables'],
#   '12-05-2015': ['fruit/vegetable juice'],
#   '29-04-2015': ['other vegetables', 'fruit/vegetable juice'],
#   '28-09-2014': ['curd', 'bottled beer'],
#   '12-07-2014': ['berries'],
#   '28-01-2015': ['frozen vegetables']},
#  '3830': {'07-04-2015': ['ice cream'],
#   '10-07-2015': ['packaged fruit/vegetables', 'butter milk'],
#   '18-10-2015': ['coffee'],
#   '28-07-2014': ['yogurt'],
#   '23-08-2014': ['candy'],
#   '28-01-2014': ['cling film/bags', 'candy', 'rolls/buns'],
#   '01-04-2014': ['domestic eggs'],
#   '14-11-2014': ['coffee'],
#   '12-10-2014': ['ice cream', 'newspapers', 'pastry']},
#  '2073': {'14-05-2015': ['herbs'],
#   '30-04-2015': ['canned fish', 'chocolate'],
#   '18-06-2015': ['domestic eggs']},
#  '1847': {'14-02-2015': ['semi-finished bread'],
#   '10-01-2014': ['rolls/buns'],
#   '13-05-2014': ['newspapers', 'butter']},
#  '1223': {'30-11-2015': ['rum'],
#   '05-09-2014': ['butter', 'UHT-milk'],
#   '20-09-2014': ['flour'],
#   '18-11-2014': ['semi-finished bread', 'yogurt']},
#  '3297': {'08-02-2015': ['dessert'],
#   '30-03-2014': ['yogurt'],
#   '22-03-2014': ['butter'],
#   '29-05-2014': ['fruit/vegetable juice', 'frozen meals', 'cat food']},
#  '2818': {'22-11-2015': ['whole milk']},
#  '2507': {'30-12-2015': ['coffee'],
#   '25-08-2015': ['coffee', 'pastry'],
#   '15-05-2014': ['pastry', 'canned beer'],
#   '05-01-2015': ['long life bakery product']},
#  '3358': {'19-03-2015': ['soda'],
#   '21-02-2015': ['soda',
#    'whole milk',
#    'fruit/vegetable juice',
#    'whipped/sour cream',
#    'yogurt'],
#   '29-03-2015': ['bottled beer', 'rolls/buns'],
#   '22-10-2014': ['hard cheese', 'chocolate'],
#   '09-09-2014': ['cream cheese ', 'pudding powder']},
#  '1930': {'18-04-2015': ['mayonnaise'],
#   '15-11-2015': ['candy', 'fruit/vegetable juice'],
#   '02-02-2015': ['specialty bar'],
#   '07-07-2014': ['UHT-milk'],
#   '28-05-2014': ['soda']},
#  '2764': {'28-12-2015': ['tropical fruit'],
#   '25-02-2015': ['bottled water'],
#   '18-04-2014': ['yogurt', 'candy'],
#   '30-03-2014': ['yogurt']},
#  '3025': {'16-06-2015': ['tea'],
#   '21-04-2015': ['bottled beer', 'herbs'],
#   '19-10-2015': ['herbs', 'white bread'],
#   '19-01-2014': ['cat food']},
#  '2201': {'03-05-2015': ['butter milk'],
#   '22-05-2015': ['hygiene articles', 'chocolate', 'rolls/buns'],
#   '04-02-2014': ['citrus fruit'],
#   '30-05-2014': ['ice cream']},
#  '3982': {'25-07-2015': ['yogurt'],
#   '27-05-2014': ['dessert'],
#   '22-11-2014': ['brown bread', 'yogurt'],
#   '13-02-2014': ['dessert'],
#   '30-10-2014': ['beverages']},
#  '2117': {'28-03-2015': ['bottled water'],
#   '02-05-2015': ['whipped/sour cream',
#    'specialty cheese',
#    'frozen vegetables'],
#   '07-11-2015': ['salt']},
#  '2706': {'12-02-2015': ['other vegetables'],
#   '14-08-2015': ['whole milk', 'cake bar'],
#   '03-10-2015': ['newspapers', 'bottled water'],
#   '22-03-2015': ['detergent', 'popcorn'],
#   '24-02-2014': ['whipped/sour cream', 'liquor'],
#   '03-05-2014': ['soda', 'sliced cheese'],
#   '10-10-2014': ['misc. beverages'],
#   '30-10-2014': ['specialty bar']},
#  '4924': {'26-08-2015': ['specialty bar'],
#   '11-06-2015': ['other vegetables', 'yogurt'],
#   '31-01-2014': ['salty snack'],
#   '19-01-2014': ['pastry', 'cereals'],
#   '01-03-2015': ['chewing gum']},
#  '3851': {'10-05-2015': ['butter'],
#   '11-08-2014': ['chocolate'],
#   '06-05-2014': ['pastry'],
#   '03-08-2014': ['other vegetables']},
#  '4036': {'26-05-2015': ['whole milk'],
#   '14-06-2014': ['hygiene articles', 'domestic eggs', 'misc. beverages'],
#   '03-08-2014': ['cream cheese '],
#   '20-06-2014': ['honey'],
#   '22-01-2014': ['cat food', 'whipped/sour cream']},
#  '2202': {'28-09-2015': ['tidbits'],
#   '24-06-2015': ['root vegetables'],
#   '28-02-2015': ['curd'],
#   '28-05-2015': ['rolls/buns'],
#   '02-01-2014': ['coffee', 'sauces'],
#   '07-08-2015': ['white wine']},
#  '1574': {'12-02-2015': ['brown bread'],
#   '04-08-2015': ['pork'],
#   '30-11-2014': ['other vegetables'],
#   '25-04-2014': ['cat food', 'margarine'],
#   '28-02-2014': ['cat food', 'roll products '],
#   '17-06-2014': ['onions', 'pastry'],
#   '12-02-2014': ['bottled beer'],
#   '15-01-2014': ['flour'],
#   '04-03-2014': ['newspapers']},
#  '1417': {'13-07-2015': ['pot plants'],
#   '18-09-2015': ['salty snack'],
#   '01-08-2014': ['frozen meals'],
#   '14-10-2014': ['cream cheese '],
#   '27-08-2014': ['other vegetables']},
#  '3204': {'08-05-2015': ['shopping bags'],
#   '25-02-2015': ['curd'],
#   '29-05-2014': ['yogurt'],
#   '16-12-2014': ['popcorn', 'frozen fish']},
#  '3445': {'01-10-2015': ['cream cheese ']},
#  '3748': {'05-03-2015': ['spread cheese'],
#   '27-03-2015': ['butter milk', 'citrus fruit'],
#   '16-02-2014': ['pastry', 'brown bread']},
#  '4061': {'09-05-2015': ['berries'],
#   '03-05-2014': ['canned beer'],
#   '04-07-2014': ['dish cleaner', 'frozen potato products']},
#  '2855': {'09-09-2015': ['soda'],
#   '03-02-2015': ['herbs', 'rice'],
#   '05-08-2015': ['frozen dessert', 'misc. beverages'],
#   '17-01-2014': ['coffee'],
#   '25-05-2014': ['UHT-milk'],
#   '13-06-2014': ['cat food', 'processed cheese', 'rolls/buns'],
#   '07-11-2014': ['hygiene articles']},
#  '4548': {'28-07-2015': ['root vegetables'],
#   '30-05-2015': ['cream cheese '],
#   '02-01-2014': ['other vegetables'],
#   '20-10-2014': ['yogurt'],
#   '17-03-2014': ['napkins'],
#   '09-10-2014': ['onions', 'brown bread']},
#  '3881': {'07-04-2015': ['canned beer'],
#   '02-04-2015': ['other vegetables', 'domestic eggs'],
#   '16-12-2014': ['frozen vegetables'],
#   '20-04-2014': ['other vegetables', 'rice'],
#   '04-06-2014': ['waffles', 'specialty chocolate']},
#  '3864': {'12-12-2015': ['specialty bar', 'long life bakery product'],
#   '26-08-2015': ['sugar'],
#   '29-10-2014': ['soda'],
#   '26-03-2014': ['newspapers'],
#   '30-12-2014': ['sliced cheese'],
#   '01-05-2014': ['cooking chocolate'],
#   '26-12-2014': ['long life bakery product', 'butter']},
#  '2766': {'19-08-2015': ['oil', 'whole milk'],
#   '01-12-2014': ['long life bakery product'],
#   '27-05-2014': ['candles', 'coffee']},
#  '3953': {'13-05-2015': ['pip fruit', 'brown bread'],
#   '19-05-2014': ['root vegetables'],
#   '13-05-2014': ['red/blush wine', 'bottled beer']},
#  '4526': {'24-08-2015': ['rolls/buns', 'rolls/buns'],
#   '18-01-2015': ['whipped/sour cream'],
#   '21-08-2015': ['yogurt'],
#   '31-08-2014': ['margarine'],
#   '19-12-2014': ['other vegetables', 'cake bar'],
#   '28-10-2014': ['sliced cheese'],
#   '17-12-2014': ['soda'],
#   '27-09-2014': ['sugar', 'shopping bags']},
#  '1468': {'09-10-2015': ['other vegetables', 'yogurt'],
#   '02-10-2014': ['frozen dessert'],
#   '12-07-2014': ['yogurt', 'bottled water'],
#   '05-02-2014': ['shopping bags', 'seasonal products'],
#   '12-04-2014': ['salty snack'],
#   '21-08-2014': ['salty snack']},
#  '4982': {'01-08-2015': ['pastry', 'butter']},
#  '3450': {'27-04-2015': ['meat', 'salty snack'],
#   '08-03-2015': ['pork', 'salty snack'],
#   '03-10-2015': ['tropical fruit'],
#   '24-12-2015': ['shopping bags', 'butter'],
#   '20-05-2014': ['pastry'],
#   '26-11-2014': ['pip fruit'],
#   '03-04-2014': ['soda']},
#  '1330': {'02-11-2015': ['soda', 'roll products '],
#   '18-05-2015': ['berries', 'soda'],
#   '11-02-2014': ['processed cheese', 'curd']},
#  '4456': {'17-04-2015': ['other vegetables', 'dishes'],
#   '21-03-2015': ['dessert', 'cling film/bags'],
#   '08-08-2015': ['cream cheese ', 'bottled water'],
#   '16-05-2015': ['other vegetables', 'whole milk'],
#   '01-05-2014': ['soda']},
#  '4606': {'30-03-2015': ['bottled beer', 'fruit/vegetable juice'],
#   '13-03-2015': ['whole milk', 'grapes'],
#   '15-05-2015': ['dishes'],
#   '30-05-2014': ['long life bakery product', 'candy'],
#   '07-11-2014': ['fruit/vegetable juice', 'salt']},
#  '3773': {'27-11-2015': ['soda', 'specialty chocolate'],
#   '17-03-2014': ['baking powder', 'mustard'],
#   '11-09-2014': ['frozen fish', 'margarine']},
#  '4593': {'12-02-2015': ['other vegetables', 'cream cheese '],
#   '07-04-2015': ['pickled vegetables', 'hard cheese'],
#   '04-08-2015': ['rolls/buns']},
#  '2244': {'28-01-2015': ['yogurt', 'sliced cheese'],
#   '29-03-2015': ['semi-finished bread', 'softener'],
#   '07-11-2014': ['rolls/buns'],
#   '19-01-2014': ['canned fish'],
#   '21-07-2014': ['misc. beverages'],
#   '09-11-2014': ['whole milk']},
#  '4296': {'26-08-2015': ['yogurt', 'oil'],
#   '28-07-2015': ['chicken', 'waffles'],
#   '15-12-2014': ['chocolate']},
#  '1114': {'10-07-2015': ['UHT-milk', 'white bread'],
#   '12-03-2015': ['dessert', 'shopping bags'],
#   '26-04-2015': ['shopping bags'],
#   '25-04-2014': ['brown bread', 'salty snack'],
#   '04-09-2014': ['shopping bags'],
#   '14-12-2014': ['citrus fruit']},
#  '3480': {'07-05-2015': ['misc. beverages', 'other vegetables'],
#   '10-08-2014': ['chocolate'],
#   '31-08-2014': ['white wine', 'frozen potato products'],
#   '29-08-2014': ['baking powder'],
#   '18-04-2014': ['bottled water']},
#  '3842': {'14-10-2015': ['white bread', 'whole milk'],
#   '03-03-2014': ['pastry'],
#   '13-10-2014': ['pot plants', 'organic products']},
#  '1715': {'21-05-2015': ['specialty chocolate', 'frozen meals'],
#   '04-07-2015': ['white wine', 'shopping bags'],
#   '03-05-2015': ['frozen meals', 'beverages'],
#   '18-10-2014': ['domestic eggs'],
#   '25-02-2014': ['specialty chocolate'],
#   '08-12-2014': ['margarine', 'bottled water']},
#  '4052': {'21-04-2015': ['whole milk', 'shopping bags'],
#   '17-05-2014': ['specialty vegetables']},
#  '2663': {'28-05-2015': ['berries', 'yogurt'],
#   '18-05-2015': ['whipped/sour cream', 'canned beer'],
#   '21-10-2015': ['semi-finished bread', 'whole milk', 'rum', 'bottled beer'],
#   '10-09-2015': ['pastry'],
#   '02-08-2014': ['waffles'],
#   '20-01-2014': ['tropical fruit', 'kitchen towels'],
#   '15-11-2014': ['shopping bags'],
#   '30-03-2014': ['shopping bags', 'packaged fruit/vegetables'],
#   '13-05-2014': ['bottled water']},
#  '1861': {'19-05-2015': ['other vegetables', 'bottled water']},
#  '2181': {'23-06-2015': ['roll products ', 'pastry'],
#   '29-04-2014': ['UHT-milk'],
#   '05-04-2014': ['soda']},
#  '2319': {'10-05-2015': ['yogurt', 'yogurt'], '05-11-2014': ['baking powder']},
#  '4277': {'06-12-2015': ['rolls/buns', 'popcorn'],
#   '25-11-2015': ['grapes'],
#   '18-02-2015': ['rolls/buns', 'shopping bags', 'newspapers'],
#   '03-08-2014': ['butter'],
#   '04-09-2014': ['hygiene articles', 'rolls/buns'],
#   '01-09-2014': ['butter'],
#   '09-08-2015': ['soda']},
#  '2193': {'07-01-2015': ['liquor (appetizer)', 'sliced cheese'],
#   '30-09-2015': ['whole milk'],
#   '14-04-2015': ['yogurt', 'whole milk'],
#   '08-10-2014': ['waffles'],
#   '26-11-2014': ['chocolate', 'candy'],
#   '05-01-2014': ['bottled beer'],
#   '12-04-2014': ['dessert'],
#   '23-10-2014': ['pastry'],
#   '11-09-2014': ['cling film/bags']},
#  '3589': {'05-10-2015': ['tropical fruit', 'curd'],
#   '04-11-2015': ['yogurt'],
#   '31-01-2015': ['rolls/buns'],
#   '07-09-2014': ['pastry'],
#   '04-03-2014': ['margarine'],
#   '24-07-2014': ['fruit/vegetable juice']},
#  '3144': {'19-06-2015': ['pet care', 'margarine'],
#   '16-08-2015': ['curd', 'margarine'],
#   '27-04-2015': ['pip fruit', 'rolls/buns'],
#   '05-06-2014': ['pastry', 'shopping bags']},
#  '4044': {'26-08-2015': ['margarine', 'napkins'],
#   '01-12-2015': ['hamburger meat'],
#   '08-07-2014': ['cream cheese ', 'semi-finished bread'],
#   '30-06-2014': ['other vegetables']},
#  '4048': {'08-05-2015': ['rolls/buns', 'domestic eggs'],
#   '03-07-2014': ['margarine'],
#   '12-04-2014': ['fruit/vegetable juice',
#    'fruit/vegetable juice',
#    'rolls/buns']},
#  '2272': {'31-01-2015': ['waffles', 'bottled beer'],
#   '07-06-2014': ['whole milk'],
#   '05-06-2014': ['napkins'],
#   '25-07-2014': ['yogurt', 'salty snack']},
#  '4637': {'14-05-2015': ['pastry', 'liquor'],
#   '06-12-2014': ['butter milk'],
#   '07-04-2014': ['napkins'],
#   '08-12-2014': ['meat spreads'],
#   '28-08-2014': ['rolls/buns']},
#  '3640': {'26-01-2015': ['white wine', 'whole milk'],
#   '13-03-2015': ['domestic eggs', 'coffee']},
#  '2599': {'22-11-2015': ['tropical fruit', 'other vegetables'],
#   '30-07-2015': ['cream cheese ', 'cake bar', 'yogurt', 'frozen vegetables'],
#   '27-01-2015': ['curd', 'salty snack']},
#  '1363': {'14-10-2015': ['margarine', 'canned vegetables'],
#   '16-06-2015': ['butter', 'whole milk'],
#   '15-01-2015': ['hard cheese'],
#   '21-07-2014': ['chocolate']},
#  '3560': {'27-09-2015': ['bottled beer', 'chocolate'],
#   '29-09-2015': ['coffee', 'soda'],
#   '21-07-2014': ['beef'],
#   '26-11-2014': ['pickled vegetables'],
#   '21-03-2014': ['liquor'],
#   '25-11-2014': ['whole milk'],
#   '27-05-2014': ['light bulbs', 'detergent']},
#  '1228': {'23-02-2015': ['beverages', 'bottled beer']},
#  '3749': {'09-03-2015': ['napkins', 'whole milk'],
#   '10-12-2014': ['waffles'],
#   '07-09-2014': ['whipped/sour cream'],
#   '29-04-2014': ['canned beer', 'specialty cheese']},
#  '1358': {'29-12-2015': ['vinegar', 'chocolate'],
#   '11-09-2015': ['yogurt', 'whipped/sour cream'],
#   '15-12-2014': ['whipped/sour cream', 'newspapers'],
#   '16-10-2014': ['whipped/sour cream', 'Instant food products']},
#  '2586': {'26-10-2015': ['cling film/bags', 'whipped/sour cream']},
#  '4626': {'24-12-2015': ['rolls/buns', 'root vegetables'],
#   '02-07-2014': ['pastry'],
#   '23-03-2014': ['canned beer', 'potato products']},
#  '1857': {'10-09-2015': ['pip fruit', 'chocolate']},
#  '2646': {'11-11-2015': ['root vegetables', 'specialty chocolate'],
#   '03-06-2015': ['liver loaf'],
#   '23-10-2014': ['pastry']},
#  '4242': {'09-12-2015': ['whole milk', 'canned fruit'],
#   '30-01-2014': ['brown bread']},
#  '2344': {'14-02-2015': ['root vegetables', 'soda'],
#   '19-04-2015': ['other vegetables', 'oil', 'candy'],
#   '14-04-2015': ['root vegetables', 'bottled water', 'whipped/sour cream'],
#   '20-11-2014': ['frozen meals', 'whole milk', 'root vegetables'],
#   '22-02-2014': ['napkins', 'newspapers']},
#  '1646': {'15-08-2015': ['sliced cheese', 'rolls/buns'],
#   '28-08-2015': ['butter', 'whole milk'],
#   '14-03-2014': ['newspapers'],
#   '15-11-2014': ['sparkling wine'],
#   '17-06-2014': ['white bread', 'frozen vegetables'],
#   '21-07-2014': ['shopping bags', 'hygiene articles']},
#  '4645': {'29-12-2015': ['soda', 'rolls/buns'],
#   '06-12-2015': ['bottled beer', 'yogurt'],
#   '10-11-2014': ['baking powder'],
#   '13-12-2014': ['brown bread'],
#   '02-06-2014': ['butter'],
#   '04-12-2014': ['soda'],
#   '25-07-2015': ['fruit/vegetable juice'],
#   '05-02-2014': ['oil', 'waffles']},
#  '3154': {'10-04-2015': ['root vegetables', 'sliced cheese'],
#   '05-01-2015': ['shopping bags'],
#   '04-12-2014': ['other vegetables']},
#  '2037': {'19-04-2015': ['grapes', 'pastry'],
#   '05-05-2014': ['curd', 'napkins'],
#   '13-04-2014': ['domestic eggs']},
#  '2078': {'16-10-2015': ['pork', 'newspapers'],
#   '14-05-2014': ['shopping bags', 'cream cheese ']},
#  '2444': {'12-05-2015': ['yogurt', 'soda'],
#   '17-06-2015': ['curd', 'fruit/vegetable juice'],
#   '19-06-2014': ['rolls/buns']},
#  '2100': {'13-10-2015': ['citrus fruit', 'whole milk'],
#   '05-07-2015': ['specialty cheese', 'coffee'],
#   '20-03-2014': ['butter'],
#   '13-05-2014': ['yogurt']},
#  '4689': {'04-06-2015': ['UHT-milk', 'pastry'],
#   '28-11-2014': ['soda', 'pastry']},
#  '4430': {'22-02-2015': ['hamburger meat', 'other vegetables'],
#   '02-12-2015': ['tropical fruit', 'curd'],
#   '17-02-2014': ['pip fruit', 'margarine'],
#   '21-05-2014': ['cream cheese '],
#   '03-10-2014': ['whipped/sour cream']},
#  '1997': {'26-10-2015': ['pip fruit', 'beverages'],
#   '28-12-2015': ['pip fruit', 'pastry'],
#   '20-08-2015': ['newspapers', 'bottled beer'],
#   '21-07-2015': ['white bread', 'brown bread'],
#   '06-06-2015': ['processed cheese', 'pickled vegetables'],
#   '30-10-2014': ['shopping bags', 'soda']},
#  '3414': {'05-02-2015': ['bottled beer', 'other vegetables'],
#   '23-10-2015': ['chewing gum'],
#   '02-04-2014': ['cream cheese '],
#   '22-05-2014': ['whole milk', 'cream cheese ', 'napkins']},
#  '2289': {'06-09-2015': ['ice cream', 'fruit/vegetable juice'],
#   '03-07-2014': ['rolls/buns'],
#   '17-08-2014': ['whole milk'],
#   '20-11-2014': ['whole milk'],
#   '05-02-2014': ['shopping bags', 'red/blush wine'],
#   '08-02-2014': ['beverages']},
#  '3137': {'24-08-2015': ['other vegetables', 'misc. beverages'],
#   '11-09-2014': ['newspapers'],
#   '26-08-2014': ['UHT-milk'],
#   '27-02-2014': ['long life bakery product', 'whipped/sour cream', 'soda'],
#   '23-02-2014': ['sugar'],
#   '13-07-2014': ['rolls/buns'],
#   '18-10-2014': ['coffee'],
#   '29-11-2014': ['newspapers', 'spread cheese']},
#  '1696': {'01-03-2015': ['whole milk', 'chewing gum'],
#   '23-08-2014': ['root vegetables'],
#   '06-09-2014': ['coffee'],
#   '17-06-2014': ['cream cheese ', 'yogurt']},
#  '1332': {'03-04-2015': ['rolls/buns', 'canned fish'],
#   '02-12-2015': ['bottled water',
#    'Instant food products',
#    'butter milk',
#    'mayonnaise'],
#   '18-04-2014': ['other vegetables'],
#   '16-07-2014': ['hard cheese']},
#  '4748': {'24-03-2015': ['root vegetables', 'yogurt'],
#   '23-03-2015': ['newspapers', 'napkins'],
#   '19-04-2014': ['whole milk']},
#  '4505': {'17-04-2015': ['dishes', 'other vegetables'],
#   '24-06-2014': ['berries'],
#   '27-11-2014': ['soda'],
#   '18-01-2014': ['other vegetables'],
#   '30-12-2014': ['root vegetables', 'domestic eggs', 'chocolate']},
#  '4336': {'27-04-2015': ['whipped/sour cream', 'newspapers'],
#   '10-10-2015': ['pot plants', 'snack products'],
#   '10-09-2015': ['soda'],
#   '25-09-2015': ['prosecco'],
#   '28-11-2014': ['chocolate'],
#   '12-10-2014': ['brown bread']},
#  '2800': {'17-03-2015': ['sauces', 'long life bakery product'],
#   '02-10-2015': ['margarine', 'soda'],
#   '02-02-2015': ['other vegetables'],
#   '21-06-2015': ['brown bread'],
#   '29-10-2014': ['frozen fish']},
#  '3537': {'12-07-2015': ['semi-finished bread', 'coffee'],
#   '25-01-2015': ['yogurt'],
#   '24-09-2015': ['curd'],
#   '10-08-2014': ['cookware'],
#   '21-06-2014': ['cream cheese '],
#   '26-03-2014': ['coffee', 'bottled water']},
#  '1331': {'29-04-2015': ['whipped/sour cream', 'misc. beverages'],
#   '29-11-2015': ['root vegetables'],
#   '06-04-2014': ['fruit/vegetable juice']},
#  '1140': {'26-06-2015': ['other vegetables', 'cling film/bags'],
#   '01-05-2015': ['other vegetables', 'curd', 'waffles']},
#  '1976': {'14-10-2015': ['root vegetables', 'bottled water']},
#  '3353': {'13-04-2015': ['yogurt', 'baking powder'],
#   '14-08-2015': ['waffles', 'whole milk'],
#   '24-01-2014': ['yogurt', 'sparkling wine'],
#   '13-07-2014': ['UHT-milk', 'sliced cheese'],
#   '10-05-2014': ['soda', 'yogurt']},
#  '2190': {'14-05-2015': ['rolls/buns', 'root vegetables'],
#   '11-10-2015': ['napkins']},
#  '3221': {'29-06-2015': ['soda', 'pastry'],
#   '01-04-2015': ['berries'],
#   '13-01-2015': ['sweet spreads'],
#   '28-10-2014': ['other vegetables'],
#   '16-01-2014': ['bottled water', 'house keeping products'],
#   '09-09-2014': ['spices'],
#   '28-07-2014': ['rolls/buns', 'detergent'],
#   '30-01-2014': ['chocolate'],
#   '17-03-2014': ['fruit/vegetable juice', 'fruit/vegetable juice']},
#  '4878': {'21-09-2015': ['packaged fruit/vegetables', 'pickled vegetables'],
#   '13-09-2014': ['whipped/sour cream']},
#  '2291': {'20-09-2015': ['roll products ', 'brown bread'],
#   '10-04-2015': ['canned fish'],
#   '29-09-2014': ['other vegetables'],
#   '26-03-2014': ['domestic eggs', 'packaged fruit/vegetables'],
#   '14-08-2014': ['canned beer']},
#  '2542': {'08-03-2015': ['yogurt', 'napkins'],
#   '24-11-2015': ['root vegetables', 'margarine'],
#   '01-01-2014': ['bottled water']},
#  '3770': {'13-01-2015': ['long life bakery product', 'curd']},
#  '3892': {'20-07-2015': ['herbs', 'yogurt'],
#   '07-04-2014': ['specialty vegetables']},
#  '2515': {'22-07-2015': ['shopping bags', 'rolls/buns'],
#   '27-01-2014': ['tropical fruit'],
#   '01-09-2014': ['shopping bags', 'yogurt'],
#   '22-10-2014': ['flower (seeds)'],
#   '12-12-2014': ['bottled beer']},
#  '4687': {'13-01-2015': ['fruit/vegetable juice', 'cat food'],
#   '23-09-2015': ['other vegetables', 'frozen vegetables'],
#   '08-04-2014': ['domestic eggs'],
#   '13-06-2014': ['soda', 'processed cheese']},
#  '3743': {'06-05-2015': ['sliced cheese', 'cake bar'],
#   '03-07-2014': ['butter'],
#   '13-08-2014': ['brown bread', 'domestic eggs'],
#   '16-10-2014': ['curd', 'brown bread'],
#   '06-01-2014': ['soda', 'photo/film', 'domestic eggs'],
#   '22-12-2014': ['pickled vegetables', 'hard cheese']},
#  '1031': {'15-10-2015': ['other vegetables', 'berries'],
#   '04-03-2014': ['pot plants']},
#  '4245': {'04-06-2015': ['yogurt', 'whipped/sour cream'],
#   '15-07-2014': ['whole milk'],
#   '13-09-2014': ['whole milk'],
#   '21-11-2014': ['tropical fruit']},
#  '1851': {'29-06-2015': ['whole milk', 'other vegetables'],
#   '11-07-2015': ['mayonnaise', 'beverages'],
#   '12-02-2014': ['root vegetables'],
#   '11-08-2014': ['flour', 'ready soups']},
#  '1788': {'20-12-2015': ['berries', 'mayonnaise'],
#   '15-04-2015': ['canned beer'],
#   '05-12-2015': ['citrus fruit', 'frozen vegetables'],
#   '02-12-2014': ['other vegetables'],
#   '19-09-2014': ['brown bread'],
#   '09-07-2014': ['long life bakery product', 'yogurt']},
#  '3166': {'15-01-2015': ['waffles', 'cat food'],
#   '14-03-2015': ['UHT-milk'],
#   '03-05-2014': ['whole milk', 'house keeping products'],
#   '22-06-2014': ['specialty bar'],
#   '08-11-2014': ['other vegetables']},
#  '4108': {'27-09-2015': ['yogurt', 'butter milk'],
#   '21-07-2015': ['whole milk', 'coffee'],
#   '13-09-2014': ['chewing gum'],
#   '27-08-2014': ['domestic eggs']},
#  '4078': {'25-04-2015': ['specialty chocolate', 'pip fruit'],
#   '18-04-2015': ['shopping bags'],
#   '14-11-2015': ['newspapers', 'fruit/vegetable juice'],
#   '27-09-2014': ['cream cheese '],
#   '11-01-2014': ['hard cheese'],
#   '21-06-2014': ['soda', 'margarine']},
#  '1784': {'26-09-2015': ['curd', 'semi-finished bread'],
#   '26-05-2015': ['other vegetables'],
#   '05-09-2014': ['rolls/buns']},
#  '4001': {'21-06-2015': ['soda', 'margarine'],
#   '30-03-2015': ['candy', 'candy'],
#   '11-06-2014': ['soda']},
#  '3202': {'14-11-2015': ['butter', 'soda']},
#  '1939': {'15-07-2015': ['whole milk', 'long life bakery product'],
#   '30-10-2015': ['sliced cheese', 'newspapers'],
#   '02-07-2015': ['tropical fruit'],
#   '28-03-2014': ['yogurt', 'shopping bags'],
#   '02-02-2014': ['whipped/sour cream']},
#  '2530': {'30-08-2015': ['other vegetables', 'waffles'],
#   '13-06-2015': ['yogurt', 'cling film/bags'],
#   '30-10-2014': ['sliced cheese'],
#   '06-08-2014': ['cream cheese ', 'shopping bags']},
#  '2893': {'12-12-2015': ['canned fish', 'oil'],
#   '19-01-2014': ['rolls/buns'],
#   '16-04-2014': ['pickled vegetables'],
#   '02-11-2014': ['white wine']},
#  '1123': {'12-11-2015': ['soda', 'canned vegetables'],
#   '31-01-2015': ['rolls/buns', 'cling film/bags'],
#   '28-12-2014': ['whole milk'],
#   '09-08-2014': ['oil', 'yogurt']},
#  '1098': {'07-05-2015': ['napkins', 'rolls/buns'],
#   '12-11-2015': ['other vegetables'],
#   '27-09-2015': ['bottled water', 'cat food'],
#   '19-01-2015': ['shopping bags', 'cat food'],
#   '05-08-2015': ['hard cheese', 'whole milk', 'canned beer'],
#   '25-02-2014': ['dessert'],
#   '19-07-2014': ['candy']},
#  '4319': {'21-05-2015': ['UHT-milk', 'frozen fish'],
#   '08-11-2015': ['fruit/vegetable juice', 'bottled water'],
#   '26-10-2015': ['hard cheese'],
#   '29-09-2014': ['butter'],
#   '10-03-2014': ['shopping bags'],
#   '29-05-2014': ['detergent']},
#  '4761': {'01-03-2015': ['other vegetables', 'curd'],
#   '08-09-2015': ['newspapers', 'soda'],
#   '24-11-2014': ['white bread', 'margarine', 'baking powder'],
#   '23-05-2014': ['frozen fish', 'ketchup']},
#  '3790': {'26-07-2015': ['domestic eggs', 'sweet spreads'],
#   '28-10-2015': ['coffee'],
#   '31-07-2014': ['whole milk'],
#   '24-04-2014': ['yogurt'],
#   '09-06-2014': ['yogurt']},
#  '4450': {'30-07-2015': ['condensed milk', 'pastry'],
#   '01-02-2014': ['condensed milk'],
#   '31-10-2014': ['bottled beer', 'rolls/buns']},
#  '2434': {'18-09-2015': ['coffee', 'cling film/bags'],
#   '09-12-2014': ['detergent', 'pet care']},
#  '3779': {'10-11-2015': ['white bread', 'long life bakery product'],
#   '10-10-2015': ['domestic eggs'],
#   '15-09-2015': ['berries'],
#   '27-10-2014': ['pastry'],
#   '27-09-2014': ['butter milk'],
#   '27-04-2014': ['meat spreads']},
#  '1613': {'03-08-2015': ['canned vegetables', 'flour'],
#   '08-08-2015': ['cream cheese '],
#   '06-04-2015': ['whipped/sour cream'],
#   '17-01-2014': ['pastry'],
#   '19-11-2014': ['salt'],
#   '02-08-2014': ['whole milk', 'butter']},
#  '3209': {'28-12-2015': ['newspapers', 'salty snack'],
#   '25-01-2015': ['newspapers'],
#   '25-12-2015': ['UHT-milk'],
#   '08-04-2014': ['liquor'],
#   '15-03-2014': ['rolls/buns']},
#  '4895': {'07-09-2015': ['domestic eggs', 'domestic eggs'],
#   '21-07-2015': ['pastry', 'salty snack'],
#   '01-06-2015': ['specialty bar']},
#  '1654': {'25-03-2015': ['shopping bags', 'rum'],
#   '09-11-2015': ['citrus fruit', 'root vegetables'],
#   '29-04-2015': ['frozen potato products', 'frozen vegetables'],
#   '07-06-2014': ['other vegetables'],
#   '26-11-2014': ['other vegetables'],
#   '08-09-2014': ['butter'],
#   '06-04-2014': ['frozen dessert'],
#   '10-08-2014': ['cream cheese ', 'female sanitary products']},
#  '1126': {'29-04-2015': ['whole milk', 'long life bakery product'],
#   '17-05-2015': ['root vegetables', 'napkins'],
#   '02-11-2014': ['whipped/sour cream']},
#  '1254': {'19-04-2015': ['specialty bar', 'specialty chocolate'],
#   '03-03-2014': ['napkins']},
#  '3168': {'02-05-2015': ['flour', 'pudding powder'],
#   '26-03-2014': ['tropical fruit', 'sugar'],
#   '19-03-2014': ['brown bread']},
#  '1892': {'30-09-2015': ['citrus fruit', 'oil'],
#   '24-04-2015': ['yogurt', 'canned beer'],
#   '08-03-2015': ['specialty bar'],
#   '21-07-2014': ['pastry'],
#   '05-08-2014': ['waffles']},
#  '1936': {'20-05-2015': ['dishes', 'newspapers'],
#   '15-08-2015': ['meat spreads']},
#  '3132': {'30-07-2015': ['yogurt', 'waffles'],
#   '29-08-2015': ['UHT-milk', 'cream cheese '],
#   '14-09-2014': ['bottled beer']},
#  '4316': {'11-01-2015': ['other vegetables', 'butter'],
#   '28-02-2014': ['shopping bags', 'rolls/buns'],
#   '31-08-2014': ['detergent', 'canned beer'],
#   '04-08-2014': ['bottled water'],
#   '03-05-2014': ['soda', 'soda'],
#   '17-08-2014': ['pot plants'],
#   '02-01-2014': ['candy'],
#   '05-10-2014': ['soft cheese']},
#  '4375': {'05-10-2015': ['domestic eggs', 'sugar'],
#   '29-04-2015': ['soda', 'canned beer'],
#   '01-08-2014': ['domestic eggs'],
#   '30-10-2014': ['frozen fish'],
#   '31-01-2014': ['butter', 'waffles']},
#  '3468': {'08-07-2015': ['vinegar', 'salty snack'],
#   '14-11-2015': ['tropical fruit', 'canned vegetables'],
#   '02-06-2014': ['yogurt'],
#   '21-01-2014': ['butter', 'dish cleaner']},
#  '2488': {'19-08-2015': ['onions', 'root vegetables'],
#   '26-08-2014': ['bottled water', 'other vegetables', 'newspapers']},
#  '1769': {'30-12-2015': ['whole milk', 'onions'],
#   '16-07-2014': ['canned vegetables']},
#  '4937': {'10-04-2015': ['coffee', 'newspapers'],
#   '28-06-2015': ['other vegetables', 'coffee'],
#   '14-02-2015': ['bottled water'],
#   '22-06-2014': ['fruit/vegetable juice'],
#   '06-09-2014': ['whipped/sour cream'],
#   '30-09-2014': ['hard cheese']},
#  '3389': {'17-08-2015': ['cream cheese ', 'other vegetables'],
#   '26-01-2015': ['root vegetables', 'newspapers'],
#   '07-12-2014': ['butter milk'],
#   '20-07-2014': ['newspapers'],
#   '30-06-2014': ['chocolate', 'yogurt']},
#  '1439': {'13-08-2015': ['whole milk', 'whole milk']},
#  '2065': {'22-01-2015': ['other vegetables', 'coffee'],
#   '01-03-2014': ['white bread'],
#   '28-11-2014': ['whipped/sour cream', 'soda'],
#   '28-01-2014': ['other vegetables'],
#   '20-07-2014': ['pastry'],
#   '20-10-2014': ['soda', 'sugar']},
#  '3686': {'01-04-2015': ['pip fruit', 'coffee'],
#   '06-01-2015': ['whole milk'],
#   '29-08-2015': ['other vegetables'],
#   '03-03-2014': ['specialty chocolate']},
#  '2774': {'28-10-2015': ['soda', 'dessert'],
#   '26-03-2014': ['shopping bags'],
#   '28-06-2014': ['whole milk', 'domestic eggs']},
#  '2204': {'16-07-2015': ['detergent', 'bottled beer'],
#   '27-09-2015': ['liquor (appetizer)'],
#   '13-06-2014': ['sliced cheese'],
#   '09-10-2014': ['brown bread', 'popcorn'],
#   '02-04-2014': ['bottled beer']},
#  '4833': {'10-03-2015': ['pip fruit', 'dog food'],
#   '27-04-2014': ['rolls/buns'],
#   '17-08-2014': ['whole milk']},
#  '1477': {'08-02-2015': ['rolls/buns', 'cream cheese '],
#   '16-05-2015': ['liquor (appetizer)', 'coffee'],
#   '21-11-2014': ['frozen vegetables', 'other vegetables'],
#   '14-03-2014': ['beverages']},
#  '4697': {'11-09-2015': ['bottled water', 'pastry'],
#   '07-05-2014': ['bottled water'],
#   '03-11-2014': ['bottled water', 'shopping bags']},
#  '2435': {'29-09-2015': ['beef', 'whole milk'],
#   '30-08-2015': ['whole milk', 'other vegetables'],
#   '02-02-2014': ['dessert'],
#   '30-10-2014': ['cat food']},
#  '2164': {'19-03-2015': ['semi-finished bread', 'fruit/vegetable juice'],
#   '24-11-2015': ['whole milk', 'pasta', 'curd', 'butter milk'],
#   '08-10-2015': ['other vegetables', 'coffee'],
#   '27-10-2014': ['spices'],
#   '19-11-2014': ['bottled beer'],
#   '30-09-2014': ['sugar'],
#   '31-01-2014': ['curd cheese'],
#   '16-06-2014': ['cream cheese '],
#   '05-02-2014': ['ice cream']},
#  '3557': {'02-02-2015': ['bottled water', 'soft cheese'],
#   '24-05-2015': ['whole milk', 'cling film/bags'],
#   '06-05-2014': ['brown bread']},
#  '3615': {'13-08-2015': ['spread cheese', 'popcorn'],
#   '02-09-2015': ['newspapers', 'brown bread'],
#   '13-06-2014': ['whole milk'],
#   '21-04-2014': ['hygiene articles']},
#  '1902': {'21-10-2015': ['ice cream', 'yogurt'],
#   '14-12-2014': ['whipped/sour cream']},
#  '4390': {'20-01-2015': ['coffee', 'soft cheese'],
#   '15-11-2014': ['beverages']},
#  '1985': {'26-11-2015': ['whole milk', 'rolls/buns'],
#   '18-05-2014': ['whole milk', 'dessert'],
#   '06-06-2014': ['bottled water']},
#  '1265': {'29-09-2015': ['tropical fruit', 'red/blush wine'],
#   '13-04-2015': ['yogurt'],
#   '03-10-2015': ['brown bread'],
#   '19-01-2015': ['other vegetables', 'domestic eggs'],
#   '07-03-2015': ['curd', 'specialty chocolate', 'pastry'],
#   '05-12-2014': ['canned fish', 'root vegetables', 'waffles'],
#   '01-02-2014': ['whole milk', 'soda']},
#  '2023': {'31-08-2015': ['bottled beer', 'roll products '],
#   '31-03-2014': ['other vegetables']},
#  '4288': {'25-09-2015': ['ham', 'male cosmetics'],
#   '13-11-2015': ['whipped/sour cream', 'pastry'],
#   '26-05-2015': ['white wine'],
#   '24-09-2014': ['canned beer'],
#   '20-06-2014': ['frozen potato products']},
#  '2261': {'29-06-2015': ['packaged fruit/vegetables', 'misc. beverages'],
#   '18-06-2015': ['packaged fruit/vegetables'],
#   '25-07-2014': ['brown bread'],
#   '21-01-2014': ['oil']},
#  '3073': {'17-01-2015': ['nut snack', 'sliced cheese'],
#   '06-07-2014': ['pastry']},
#  '2406': {'04-09-2015': ['whole milk', 'other vegetables'],
#   '24-10-2015': ['root vegetables', 'dish cleaner'],
#   '27-10-2014': ['chocolate marshmallow'],
#   '12-03-2014': ['salt'],
#   '25-09-2014': ['yogurt'],
#   '10-03-2015': ['pastry']},
#  '3983': {'20-07-2015': ['butter milk', 'sugar'],
#   '09-09-2015': ['sweet spreads',
#    'butter',
#    'long life bakery product',
#    'napkins',
#    'white bread']},
#  '1737': {'23-01-2015': ['liquor', 'tropical fruit'],
#   '05-09-2015': ['condensed milk'],
#   '09-05-2015': ['instant coffee', 'yogurt', 'domestic eggs'],
#   '28-08-2014': ['detergent'],
#   '04-09-2014': ['flour']},
#  '1304': {'30-04-2015': ['whipped/sour cream', 'dishes'],
#   '17-08-2015': ['whole milk'],
#   '07-06-2014': ['other vegetables']},
#  '4227': {'20-08-2015': ['coffee', 'yogurt'],
#   '25-07-2014': ['long life bakery product'],
#   '08-08-2014': ['rolls/buns']},
#  '3987': {'17-06-2015': ['pastry', 'rolls/buns'],
#   '19-08-2015': ['domestic eggs'],
#   '31-08-2014': ['yogurt']},
#  '4127': {'12-11-2015': ['herbs', 'curd'],
#   '11-04-2015': ['margarine', 'domestic eggs'],
#   '18-03-2014': ['mustard']},
#  '1734': {'20-03-2015': ['rum', 'brown bread'],
#   '08-06-2015': ['pork', 'rolls/buns'],
#   '15-02-2015': ['baking powder', 'frozen vegetables'],
#   '07-11-2014': ['yogurt'],
#   '17-08-2014': ['beverages']},
#  '2770': {'15-07-2015': ['coffee', 'coffee'], '29-08-2014': ['pip fruit']},
#  '1454': {'13-01-2015': ['tropical fruit', 'rolls/buns'],
#   '22-10-2015': ['coffee', 'flour'],
#   '28-01-2014': ['rolls/buns'],
#   '03-05-2014': ['fruit/vegetable juice']},
#  '2256': {'21-08-2015': ['whipped/sour cream', 'domestic eggs'],
#   '02-08-2014': ['frozen vegetables'],
#   '24-11-2014': ['butter']},
#  '2625': {'18-11-2015': ['specialty bar', 'long life bakery product'],
#   '22-03-2015': ['shopping bags', 'cream cheese '],
#   '06-03-2015': ['baking powder', 'curd'],
#   '18-02-2015': ['whole milk', 'newspapers'],
#   '08-04-2015': ['yogurt', 'frozen meals', 'other vegetables'],
#   '14-12-2014': ['specialty chocolate'],
#   '21-07-2014': ['bottled water'],
#   '06-09-2014': ['yogurt'],
#   '24-09-2014': ['whole milk']},
#  '4335': {'05-12-2015': ['whole milk', 'frozen vegetables'],
#   '10-06-2015': ['shopping bags', 'napkins'],
#   '12-10-2015': ['bottled water'],
#   '05-01-2015': ['other vegetables'],
#   '01-03-2014': ['canned beer'],
#   '17-07-2014': ['margarine'],
#   '28-06-2014': ['fruit/vegetable juice', 'pickled vegetables']},
#  '3738': {'24-05-2015': ['waffles', 'newspapers'],
#   '15-07-2015': ['rolls/buns'],
#   '01-04-2015': ['yogurt', 'frozen vegetables'],
#   '30-12-2015': ['flour']},
#  '2394': {'19-08-2015': ['whole milk', 'condensed milk'],
#   '30-08-2015': ['domestic eggs', 'yogurt', 'soda'],
#   '18-06-2014': ['whipped/sour cream', 'decalcifier'],
#   '18-10-2014': ['nuts/prunes'],
#   '05-06-2014': ['curd'],
#   '24-02-2014': ['whipped/sour cream', 'coffee'],
#   '20-05-2014': ['canned beer', 'semi-finished bread'],
#   '17-02-2015': ['meat spreads']},
#  '1927': {'15-05-2015': ['white wine', 'oil'],
#   '20-06-2014': ['mayonnaise', 'flour']},
#  '3681': {'14-10-2015': ['soft cheese', 'frozen vegetables'],
#   '01-01-2014': ['whipped/sour cream', 'dishes'],
#   '19-05-2014': ['specialty fat'],
#   '09-06-2014': ['frozen vegetables']},
#  '1728': {'15-08-2015': ['bottled water', 'ice cream'],
#   '22-06-2014': ['rum'],
#   '18-10-2014': ['processed cheese']},
#  '4708': {'14-04-2015': ['other vegetables', 'canned beer'],
#   '02-10-2015': ['brown bread'],
#   '06-06-2015': ['processed cheese'],
#   '20-03-2015': ['specialty bar', 'salty snack'],
#   '09-11-2014': ['frozen fish']},
#  '1010': {'31-07-2015': ['candles', 'rolls/buns'],
#   '27-08-2014': ['bottled water'],
#   '05-03-2014': ['coffee', 'UHT-milk'],
#   '23-08-2014': ['specialty bar'],
#   '10-04-2014': ['kitchen towels', 'sliced cheese']},
#  '3735': {'20-04-2015': ['seasonal products', 'margarine'],
#   '27-04-2015': ['pet care'],
#   '13-07-2014': ['whole milk']},
#  '3331': {'19-05-2015': ['ice cream', 'soda'],
#   '25-07-2015': ['flour', 'shopping bags']},
#  '2383': {'05-10-2015': ['long life bakery product', 'pastry'],
#   '02-01-2015': ['yogurt', 'specialty chocolate'],
#   '25-05-2014': ['condensed milk'],
#   '13-01-2014': ['yogurt'],
#   '18-09-2014': ['butter']},
#  '1160': {'20-11-2015': ['tropical fruit', 'mustard'],
#   '21-08-2015': ['coffee', 'bottled beer'],
#   '06-02-2014': ['root vegetables'],
#   '04-02-2014': ['whole milk']},
#  '4890': {'22-04-2015': ['whole milk', 'other vegetables'],
#   '30-11-2014': ['margarine', 'sugar'],
#   '08-11-2014': ['fruit/vegetable juice', 'brown bread']},
#  '3513': {'29-05-2015': ['waffles', 'bottled beer'],
#   '29-08-2015': ['condensed milk', 'coffee']},
#  '2525': {'14-01-2015': ['soda', 'shopping bags'],
#   '04-03-2014': ['chocolate']},
#  '3708': {'03-09-2015': ['other vegetables', 'cake bar'],
#   '27-10-2014': ['pip fruit'],
#   '17-07-2014': ['cream cheese ']},
#  '4746': {'06-06-2015': ['cake bar', 'whole milk'],
#   '09-12-2015': ['yogurt'],
#   '08-07-2014': ['sugar', 'semi-finished bread'],
#   '12-02-2014': ['bottled water'],
#   '02-01-2014': ['margarine', 'newspapers']},
#  '4784': {'11-09-2015': ['coffee', 'napkins'], '28-10-2014': ['soft cheese']},
#  '2051': {'02-01-2015': ['domestic eggs', 'cocoa drinks'],
#   '11-09-2015': ['newspapers',
#    'pip fruit',
#    'whipped/sour cream',
#    'hygiene articles'],
#   '14-11-2015': ['whole milk', 'coffee'],
#   '20-04-2015': ['brown bread', 'other vegetables'],
#   '23-07-2015': ['ice cream', 'soda', 'root vegetables'],
#   '20-01-2014': ['rolls/buns'],
#   '03-12-2014': ['other vegetables', 'newspapers'],
#   '01-05-2014': ['flour', 'cream cheese ']},
#  '4745': {'12-04-2015': ['rolls/buns', 'soda'],
#   '29-09-2015': ['canned fish', 'shopping bags'],
#   '01-04-2014': ['soda'],
#   '14-08-2014': ['pastry'],
#   '28-03-2014': ['bottled water'],
#   '20-08-2014': ['soft cheese', 'long life bakery product']},
#  '4364': {'17-01-2015': ['dessert', 'flour'],
#   '24-12-2015': ['mayonnaise', 'fruit/vegetable juice'],
#   '05-09-2015': ['pickled vegetables'],
#   '25-05-2015': ['butter'],
#   '21-01-2014': ['yogurt'],
#   '01-02-2014': ['yogurt'],
#   '13-04-2014': ['frozen vegetables', 'sugar', 'coffee'],
#   '07-06-2014': ['rolls/buns'],
#   '24-09-2014': ['baking powder']},
#  '1493': {'23-02-2015': ['whole milk', 'napkins'],
#   '01-10-2015': ['spices'],
#   '22-05-2015': ['yogurt', 'hygiene articles'],
#   '06-03-2014': ['processed cheese', 'oil'],
#   '28-01-2014': ['root vegetables'],
#   '22-10-2014': ['UHT-milk']},
#  '1777': {'10-07-2015': ['pastry', 'fruit/vegetable juice'],
#   '22-04-2015': ['whole milk'],
#   '08-07-2015': ['fruit/vegetable juice', 'brown bread', 'pot plants'],
#   '03-12-2015': ['pip fruit', 'misc. beverages'],
#   '02-04-2014': ['sugar'],
#   '11-07-2015': ['brown bread']},
#  '2633': {'10-07-2015': ['rolls/buns', 'white wine'],
#   '14-02-2015': ['whole milk', 'root vegetables'],
#   '16-05-2014': ['other vegetables'],
#   '07-09-2014': ['frozen potato products'],
#   '28-07-2014': ['long life bakery product', 'waffles'],
#   '27-11-2015': ['waffles']},
#  '1917': {'23-01-2015': ['yogurt', 'whole milk'],
#   '25-02-2014': ['red/blush wine'],
#   '26-01-2014': ['curd cheese'],
#   '09-10-2014': ['curd']},
#  '4891': {'09-01-2015': ['butter', 'rolls/buns'],
#   '06-10-2015': ['whole milk', 'rolls/buns'],
#   '02-06-2014': ['dog food', 'cream cheese ']},
#  '3828': {'15-06-2015': ['canned fish', 'pasta'],
#   '25-04-2014': ['cat food'],
#   '24-02-2014': ['soda'],
#   '16-05-2014': ['bottled water']},
#  '2282': {'11-05-2015': ['margarine', 'white wine']},
#  '2743': {'10-08-2015': ['specialty cheese', 'candy'],
#   '05-05-2015': ['dog food', 'yogurt'],
#   '12-05-2014': ['chocolate'],
#   '26-02-2014': ['frozen potato products'],
#   '09-08-2014': ['shopping bags'],
#   '13-07-2015': ['frozen vegetables']},
#  '2704': {'18-11-2015': ['red/blush wine', 'rolls/buns'],
#   '02-08-2014': ['whole milk', 'bottled beer']},
#  '4170': {'11-07-2015': ['red/blush wine', 'fruit/vegetable juice'],
#   '11-05-2015': ['onions'],
#   '19-01-2015': ['yogurt', 'newspapers'],
#   '03-05-2015': ['instant coffee']},
#  '3867': {'07-09-2015': ['skin care', 'whipped/sour cream'],
#   '10-08-2014': ['flower soil/fertilizer'],
#   '24-07-2014': ['domestic eggs', 'napkins']},
#  '2592': {'23-04-2015': ['fruit/vegetable juice', 'margarine'],
#   '20-03-2015': ['yogurt', 'rolls/buns'],
#   '01-10-2015': ['soda'],
#   '25-09-2015': ['bottled beer'],
#   '08-09-2014': ['grapes', 'curd', 'shopping bags']},
#  '1894': {'03-10-2015': ['soda', 'soda'],
#   '04-08-2015': ['whole milk',
#    'citrus fruit',
#    'semi-finished bread',
#    'napkins'],
#   '19-08-2014': ['waffles', 'cream cheese ']},
#  '2348': {'08-09-2015': ['frozen vegetables', 'long life bakery product'],
#   '28-02-2015': ['root vegetables', 'soda'],
#   '01-11-2015': ['root vegetables', 'pastry'],
#   '22-11-2014': ['yogurt'],
#   '23-07-2014': ['shopping bags', 'chocolate']},
#  '3747': {'24-02-2015': ['butter', 'brown bread'], '05-11-2014': ['salt']},
#  '4220': {'21-08-2015': ['rolls/buns', 'rolls/buns'],
#   '10-08-2015': ['detergent', 'bottled water'],
#   '21-11-2015': ['whole milk', 'other vegetables'],
#   '05-05-2014': ['rolls/buns', 'soft cheese'],
#   '04-08-2014': ['sliced cheese', 'chocolate']},
#  '4504': {'04-09-2015': ['citrus fruit', 'soda'],
#   '24-09-2014': ['bottled beer', 'hygiene articles'],
#   '21-01-2014': ['other vegetables', 'rolls/buns', 'brown bread'],
#   '08-03-2014': ['soda'],
#   '02-03-2014': ['seasonal products', 'soups']},
#  '3175': {'23-11-2015': ['soda', 'canned fish'],
#   '05-06-2015': ['other vegetables', 'zwieback'],
#   '18-11-2014': ['processed cheese'],
#   '29-04-2014': ['rolls/buns', 'rolls/buns']},
#  '4240': {'28-06-2015': ['frozen dessert', 'shopping bags'],
#   '18-09-2015': ['whole milk', 'brown bread'],
#   '28-10-2015': ['coffee', 'soda'],
#   '29-04-2015': ['soda']},
#  '4608': {'25-11-2015': ['frozen vegetables', 'chocolate'],
#   '05-01-2015': ['canned beer', 'fruit/vegetable juice'],
#   '27-04-2015': ['ketchup'],
#   '20-07-2014': ['whole milk', 'candy']},
#  '3053': {'03-12-2015': ['brown bread', 'chewing gum'],
#   '25-12-2015': ['chocolate', 'curd'],
#   '13-12-2014': ['other vegetables']},
#  '4096': {'29-06-2015': ['butter milk', 'seasonal products'],
#   '13-06-2014': ['yogurt', 'fruit/vegetable juice'],
#   '20-04-2014': ['napkins'],
#   '23-05-2014': ['pasta', 'margarine']},
#  '2517': {'28-01-2015': ['yogurt', 'detergent'],
#   '22-03-2015': ['yogurt', 'sugar'],
#   '12-12-2015': ['syrup', 'whole milk'],
#   '29-09-2015': ['salt', 'other vegetables'],
#   '20-03-2015': ['domestic eggs'],
#   '12-05-2014': ['spread cheese'],
#   '26-02-2014': ['soft cheese'],
#   '17-04-2014': ['flour', 'frozen fish', 'cream cheese ']},
#  '1899': {'24-10-2015': ['liquor', 'shopping bags'],
#   '07-02-2014': ['fruit/vegetable juice'],
#   '01-03-2014': ['brown bread'],
#   '09-12-2014': ['dessert', 'chewing gum'],
#   '19-10-2015': ['Instant food products']},
#  '2934': {'11-05-2015': ['whipped/sour cream', 'chocolate'],
#   '13-09-2015': ['UHT-milk'],
#   '30-10-2014': ['butter milk'],
#   '22-03-2014': ['fruit/vegetable juice']},
#  '2508': {'27-12-2015': ['cleaner', 'cling film/bags'],
#   '21-09-2014': ['bottled water'],
#   '28-05-2014': ['frozen vegetables', 'dessert']},
#  '1527': {'14-05-2015': ['frozen vegetables', 'frozen meals'],
#   '20-04-2015': ['napkins', 'soda'],
#   '30-12-2015': ['whole milk', 'bottled water'],
#   '29-01-2014': ['domestic eggs'],
#   '15-04-2014': ['soda']},
#  '1431': {'07-11-2015': ['bottled water', 'specialty bar'],
#   '05-03-2015': ['whole milk'],
#   '13-10-2014': ['rolls/buns']},
#  '4148': {'09-02-2015': ['butter milk', 'beverages'],
# ...
#  '1750': {'08-02-2015': ['pastry', 'soda'],
#   '28-05-2014': ['shopping bags'],
#   '09-06-2014': ['baking powder', 'newspapers'],
#   '17-07-2014': ['dog food'],
#   '16-06-2014': ['shopping bags', 'rolls/buns']},
#  '2380': {'09-10-2015': ['cookware', 'pastry'],
#   '12-02-2015': ['rolls/buns', 'domestic eggs'],
#   '05-04-2014': ['pastry'],
#   '21-05-2014': ['whole milk']},
#  '3259': {'02-09-2015': ['oil', 'cream cheese '],
#   '12-03-2014': ['shopping bags'],
#   '01-02-2014': ['soda', 'dishes']},
#  '3268': {'13-07-2015': ['whole milk', 'specialty cheese'],
#   '18-04-2015': ['margarine'],
#   '31-01-2014': ['dish cleaner'],
#   '04-05-2014': ['shopping bags'],
#   '23-01-2014': ['white bread'],
#   '03-11-2014': ['cling film/bags'],
#   '06-11-2015': ['rolls/buns']},
#  '3117': {'03-03-2015': ['brown bread', 'misc. beverages'],
#   '30-09-2015': ['other vegetables', 'yogurt'],
#   '09-01-2014': ['domestic eggs'],
#   '19-03-2014': ['napkins', 'fruit/vegetable juice']},
#  '1972': {'02-06-2015': ['pasta', 'fruit/vegetable juice'],
#   '02-05-2014': ['bottled beer', 'whipped/sour cream']},
#  '1154': {'06-04-2015': ['other vegetables', 'frozen vegetables'],
#   '17-05-2015': ['whole milk', 'canned beer'],
#   '15-05-2014': ['rolls/buns']},
#  '2400': {'22-03-2015': ['tropical fruit', 'white wine'],
#   '06-02-2015': ['whole milk'],
#   '26-08-2014': ['pip fruit', 'domestic eggs'],
#   '08-03-2014': ['white bread']},
#  '3505': {'21-07-2015': ['other vegetables', 'white bread'],
#   '11-10-2015': ['domestic eggs'],
#   '30-11-2014': ['UHT-milk'],
#   '31-07-2014': ['cream cheese ', 'brown bread', 'soda'],
#   '05-08-2014': ['soft cheese'],
#   '18-03-2014': ['meat spreads', 'ketchup']},
#  '4503': {'19-12-2015': ['whipped/sour cream', 'specialty chocolate'],
#   '26-11-2015': ['coffee']},
#  '2745': {'08-04-2015': ['rolls/buns'],
#   '19-02-2015': ['oil'],
#   '21-04-2015': ['other vegetables'],
#   '29-04-2015': ['coffee'],
#   '27-01-2015': ['butter milk', 'vinegar'],
#   '27-04-2014': ['dessert']},
#  '4682': {'17-05-2015': ['other vegetables'],
#   '21-04-2014': ['toilet cleaner']},
#  '2553': {'01-02-2015': ['tropical fruit'],
#   '21-06-2015': ['pip fruit', 'specialty bar'],
#   '15-08-2014': ['yogurt'],
#   '16-08-2014': ['flower soil/fertilizer'],
#   '26-12-2014': ['bottled water', 'rolls/buns']},
#  '3985': {'18-02-2015': ['canned beer'],
#   '24-07-2015': ['canned beer', 'candy'],
#   '23-10-2015': ['cling film/bags',
#    'whipped/sour cream',
#    'newspapers',
#    'baking powder'],
#   '22-06-2014': ['cake bar']},
#  '2741': {'28-09-2015': ['bottled beer'],
#   '17-02-2015': ['waffles', 'soda'],
#   '10-08-2014': ['canned beer'],
#   '11-09-2015': ['canned vegetables']},
#  '2642': {'01-04-2015': ['beverages'],
#   '15-06-2014': ['frozen vegetables', 'spices'],
#   '09-01-2014': ['long life bakery product', 'yogurt']},
#  '2042': {'17-11-2015': ['root vegetables'],
#   '31-08-2014': ['brown bread'],
#   '10-09-2014': ['other vegetables'],
#   '17-04-2014': ['shopping bags', 'cream cheese ', 'pasta'],
#   '19-12-2014': ['newspapers']},
#  '4669': {'27-05-2015': ['other vegetables'],
#   '13-04-2014': ['pastry'],
#   '05-08-2014': ['specialty chocolate', 'domestic eggs'],
#   '14-03-2014': ['whole milk', 'kitchen towels']},
#  '2045': {'16-08-2015': ['sweet spreads'],
#   '07-12-2015': ['grapes'],
#   '11-04-2014': ['whole milk'],
#   '05-04-2014': ['pickled vegetables'],
#   '02-04-2014': ['other vegetables', 'soft cheese'],
#   '09-07-2014': ['whole milk'],
#   '10-02-2014': ['soda', 'brandy']},
#  '2225': {'12-03-2015': ['whole milk'],
#   '28-04-2015': ['brown bread', 'yogurt'],
#   '13-10-2014': ['hard cheese'],
#   '29-09-2014': ['rolls/buns', 'waffles']},
#  '4494': {'02-11-2015': ['tropical fruit'],
#   '24-04-2014': ['newspapers'],
#   '26-05-2014': ['sugar'],
#   '30-11-2014': ['fruit/vegetable juice'],
#   '11-06-2014': ['frozen meals', 'dish cleaner'],
#   '08-11-2014': ['frozen dessert', 'newspapers'],
#   '27-01-2014': ['liquor'],
#   '06-08-2015': ['white bread']},
#  '3539': {'24-01-2015': ['bottled beer'],
#   '13-01-2014': ['bottled beer'],
#   '19-03-2014': ['soda'],
#   '27-08-2014': ['fruit/vegetable juice'],
#   '07-11-2014': ['whipped/sour cream', 'frozen dessert', 'pastry'],
#   '09-05-2014': ['tropical fruit']},
#  '1002': {'26-04-2015': ['sugar'],
#   '30-08-2015': ['specialty chocolate'],
#   '26-04-2014': ['whole milk'],
#   '09-02-2014': ['other vegetables']},
#  '1711': {'22-11-2015': ['yogurt'],
#   '21-03-2015': ['citrus fruit', 'shopping bags'],
#   '26-02-2015': ['whole milk'],
#   '18-06-2015': ['white bread'],
#   '23-05-2014': ['herbs'],
#   '15-12-2014': ['yogurt'],
#   '09-05-2014': ['newspapers', 'specialty chocolate']},
#  '2436': {'24-11-2015': ['whole milk'],
#   '17-02-2015': ['margarine'],
#   '12-04-2015': ['liquor', 'bottled water'],
#   '27-11-2014': ['newspapers', 'bottled water']},
#  '4665': {'26-02-2015': ['whole milk'],
#   '12-01-2014': ['rolls/buns'],
#   '03-12-2014': ['cat food'],
#   '05-11-2014': ['shopping bags', 'cake bar']},
#  '3052': {'04-07-2015': ['rolls/buns'],
#   '26-10-2014': ['hard cheese', 'rolls/buns']},
#  '4943': {'28-07-2015': ['soda'],
#   '22-10-2014': ['rolls/buns'],
#   '01-05-2014': ['other vegetables']},
#  '1323': {'03-11-2015': ['whole milk'],
#   '30-04-2015': ['beef', 'bottled beer'],
#   '18-06-2014': ['whole milk']},
#  '1604': {'04-11-2015': ['rum'],
#   '11-11-2015': ['fruit/vegetable juice'],
#   '03-02-2014': ['specialty bar']},
#  '2794': {'12-09-2015': ['specialty chocolate'],
#   '29-09-2015': ['margarine', 'whipped/sour cream'],
#   '18-02-2014': ['whole milk', 'canned beer'],
#   '13-07-2014': ['curd'],
#   '23-07-2014': ['fruit/vegetable juice']},
#  '2253': {'21-07-2015': ['white bread'], '16-12-2014': ['butter milk']},
#  '2873': {'03-09-2015': ['whipped/sour cream'],
#   '15-07-2015': ['liquor (appetizer)'],
#   '23-10-2014': ['detergent', 'soda'],
#   '28-01-2014': ['citrus fruit', 'rolls/buns'],
#   '23-05-2014': ['whole milk', 'frozen vegetables', 'newspapers'],
#   '09-10-2014': ['cake bar']},
#  '2707': {'22-06-2015': ['newspapers'],
#   '05-05-2015': ['whole milk'],
#   '07-03-2015': ['shopping bags', 'waffles'],
#   '18-03-2014': ['detergent'],
#   '30-10-2014': ['margarine', 'specialty bar']},
#  '3711': {'08-07-2015': ['berries'], '20-05-2014': ['domestic eggs']},
#  '2960': {'17-02-2015': ['pastry'],
#   '19-12-2015': ['yogurt', 'domestic eggs'],
#   '31-08-2015': ['rolls/buns', 'whole milk', 'frozen vegetables'],
#   '03-09-2014': ['canned beer'],
#   '28-11-2014': ['dishes'],
#   '11-03-2014': ['shopping bags'],
#   '14-11-2014': ['berries'],
#   '27-10-2014': ['fruit/vegetable juice']},
#  '1702': {'14-01-2015': ['bottled beer'],
#   '12-01-2014': ['pip fruit', 'yogurt'],
#   '05-05-2014': ['whipped/sour cream', 'decalcifier'],
#   '13-05-2014': ['yogurt', 'margarine'],
#   '26-02-2014': ['waffles']},
#  '4347': {'07-03-2015': ['root vegetables'], '09-07-2014': ['margarine']},
#  '2913': {'04-07-2015': ['ready soups'],
#   '14-12-2014': ['house keeping products']},
#  '3893': {'15-04-2015': ['whole milk'],
#   '08-01-2014': ['canned beer'],
#   '19-05-2014': ['rolls/buns', 'shopping bags'],
#   '09-10-2014': ['newspapers'],
#   '16-05-2014': ['roll products ']},
#  '3205': {'20-03-2015': ['detergent'],
#   '11-12-2015': ['butter', 'frozen vegetables'],
#   '05-09-2014': ['soda', 'red/blush wine'],
#   '03-06-2014': ['whipped/sour cream']},
#  '2048': {'16-12-2015': ['sugar'],
#   '24-02-2014': ['pip fruit'],
#   '30-10-2014': ['frozen vegetables'],
#   '24-11-2014': ['berries'],
#   '17-12-2014': ['other vegetables'],
#   '07-11-2014': ['fruit/vegetable juice']},
#  '2176': {'08-08-2015': ['onions'],
#   '04-02-2015': ['long life bakery product', 'whipped/sour cream'],
#   '27-09-2014': ['hard cheese'],
#   '14-05-2014': ['butter', 'bottled water']},
#  '2659': {'15-06-2015': ['yogurt'],
#   '08-05-2015': ['domestic eggs',
#    'other vegetables',
#    'nut snack',
#    'shopping bags'],
#   '08-12-2015': ['brown bread'],
#   '28-07-2014': ['hamburger meat', 'tea'],
#   '01-06-2015': ['brown bread']},
#  '3841': {'01-02-2015': ['other vegetables'],
#   '19-07-2015': ['frozen vegetables', 'domestic eggs'],
#   '29-07-2014': ['butter', 'newspapers'],
#   '27-09-2014': ['UHT-milk', 'brown bread'],
#   '01-08-2014': ['brown bread']},
#  '1077': {'12-09-2015': ['soda'],
#   '30-12-2014': ['root vegetables'],
#   '30-08-2014': ['rolls/buns', 'artif. sweetener', 'soda'],
#   '07-10-2014': ['butter'],
#   '29-09-2014': ['brown bread'],
#   '17-07-2014': ['pasta']},
#  '2403': {'28-11-2015': ['chewing gum'],
#   '14-02-2015': ['pip fruit', 'margarine', 'butter', 'napkins'],
#   '01-12-2015': ['yogurt'],
#   '14-04-2014': ['yogurt', 'hard cheese']},
#  '3324': {'24-08-2015': ['rolls/buns'],
#   '29-12-2014': ['frozen potato products'],
#   '10-11-2014': ['chewing gum', 'coffee'],
#   '07-05-2014': ['other vegetables']},
#  '4976': {'11-07-2015': ['pastry'],
#   '17-07-2015': ['liquor', 'specialty chocolate']},
#  '3894': {'06-11-2015': ['other vegetables'],
#   '25-01-2015': ['root vegetables', 'pastry'],
#   '13-12-2015': ['curd', 'UHT-milk'],
#   '10-02-2014': ['yogurt']},
#  '3652': {'18-09-2015': ['whole milk'], '15-11-2014': ['frozen vegetables']},
#  '4867': {'03-01-2015': ['salty snack'],
#   '30-09-2014': ['beef'],
#   '05-05-2014': ['newspapers', 'frozen fish']},
#  '1845': {'28-05-2015': ['rolls/buns'],
#   '07-08-2015': ['root vegetables', 'mayonnaise'],
#   '11-02-2015': ['margarine']},
#  '2233': {'28-08-2015': ['chocolate'],
#   '10-04-2015': ['bottled beer'],
#   '24-04-2014': ['other vegetables', 'domestic eggs'],
#   '29-10-2014': ['pastry']},
#  '1958': {'03-07-2015': ['cream cheese '],
#   '16-06-2014': ['whole milk', 'artif. sweetener']},
#  '1535': {'14-01-2015': ['soda'],
#   '26-06-2014': ['other vegetables'],
#   '08-06-2014': ['whole milk']},
#  '2187': {'16-08-2015': ['sugar'],
#   '22-08-2014': ['newspapers'],
#   '26-12-2014': ['domestic eggs']},
#  '4557': {'19-10-2015': ['packaged fruit/vegetables'],
#   '11-01-2014': ['soda'],
#   '14-07-2014': ['napkins', 'coffee'],
#   '12-08-2014': ['rum', 'yogurt']},
#  '1482': {'21-02-2015': ['cake bar'],
#   '24-07-2015': ['cream cheese ', 'frozen vegetables'],
#   '06-07-2015': ['soda', 'shopping bags', 'sugar'],
#   '22-10-2014': ['brown bread'],
#   '24-09-2014': ['mayonnaise', 'shopping bags']},
#  '4614': {'07-06-2015': ['butter'],
#   '24-10-2015': ['whole milk'],
#   '25-12-2014': ['sugar'],
#   '01-12-2014': ['newspapers']},
#  '1341': {'16-09-2015': ['fruit/vegetable juice'],
#   '30-10-2015': ['berries'],
#   '21-04-2014': ['yogurt', 'spices', 'chocolate'],
#   '08-11-2014': ['root vegetables', 'bottled beer', 'pastry']},
#  '4768': {'13-03-2015': ['yogurt', 'flour']},
#  '3683': {'04-12-2015': ['frozen meals'],
#   '05-12-2015': ['other vegetables'],
#   '10-06-2015': ['ice cream'],
#   '07-11-2014': ['tidbits'],
#   '05-10-2014': ['newspapers', 'curd', 'hard cheese']},
#  '3471': {'29-05-2015': ['liquor'],
#   '14-01-2015': ['rolls/buns'],
#   '12-10-2015': ['rolls/buns']},
#  '4698': {'25-10-2015': ['newspapers'],
#   '24-07-2014': ['curd'],
#   '20-01-2014': ['rolls/buns', 'specialty chocolate', 'white bread']},
#  '4134': {'28-11-2015': ['dessert'],
#   '26-12-2014': ['brown bread', 'bottled water', 'specialty bar'],
#   '30-09-2014': ['whole milk', 'coffee']},
#  '1357': {'28-07-2015': ['brown bread']},
#  '2617': {'22-05-2015': ['dessert'],
#   '19-06-2014': ['rolls/buns', 'frozen meals'],
#   '12-08-2014': ['yogurt', 'whole milk'],
#   '22-02-2014': ['yogurt'],
#   '27-05-2014': ['frozen vegetables'],
#   '16-11-2014': ['rolls/buns']},
#  '2834': {'26-12-2015': ['cream cheese '],
#   '02-12-2015': ['yogurt', 'napkins'],
#   '07-02-2014': ['soda', 'yogurt'],
#   '01-08-2014': ['sliced cheese', 'shopping bags']},
#  '1921': {'25-10-2015': ['bottled water'],
#   '23-02-2015': ['rolls/buns'],
#   '11-11-2015': ['whipped/sour cream'],
#   '12-12-2014': ['napkins'],
#   '27-03-2014': ['napkins'],
#   '11-06-2014': ['chocolate'],
#   '17-08-2014': ['hygiene articles']},
#  '1248': {'25-08-2015': ['curd'],
#   '15-12-2015': ['whole milk'],
#   '08-05-2014': ['skin care'],
#   '09-05-2014': ['frozen vegetables'],
#   '14-08-2014': ['pip fruit'],
#   '25-03-2014': ['margarine'],
#   '01-02-2014': ['butter'],
#   '24-07-2014': ['packaged fruit/vegetables']},
#  '3945': {'04-10-2015': ['onions'],
#   '25-01-2014': ['rolls/buns'],
#   '15-10-2014': ['margarine', 'cereals']},
#  '2265': {'29-07-2015': ['chewing gum'],
#   '25-09-2015': ['soft cheese',
#    'domestic eggs',
#    'dish cleaner',
#    'bathroom cleaner'],
#   '13-06-2015': ['white bread',
#    'whipped/sour cream',
#    'specialty fat',
#    'soft cheese']},
#  '1046': {'18-06-2015': ['pastry'], '24-06-2015': ['bottled water']},
#  '4563': {'16-05-2015': ['whole milk'],
#   '27-06-2015': ['other vegetables'],
#   '14-05-2015': ['canned beer', 'pastry'],
#   '20-05-2014': ['margarine'],
#   '28-01-2014': ['frozen fish', 'baking powder']},
#  '4255': {'15-08-2015': ['dishes'],
#   '02-01-2014': ['margarine'],
#   '03-11-2014': ['liquor', 'shopping bags'],
#   '29-09-2014': ['yogurt', 'brown bread']},
#  '3741': {'21-11-2015': ['other vegetables'],
#   '14-06-2015': ['pastry', 'candles'],
#   '06-08-2015': ['shopping bags',
#    'chewing gum',
#    'shopping bags',
#    'white bread']},
#  '2990': {'12-08-2015': ['specialty bar'],
#   '29-06-2015': ['canned beer', 'pastry'],
#   '23-05-2015': ['brown bread'],
#   '24-04-2014': ['curd', 'sugar'],
#   '16-07-2014': ['kitchen towels'],
#   '15-08-2014': ['long life bakery product'],
#   '31-05-2014': ['UHT-milk'],
#   '30-03-2014': ['rolls/buns', 'long life bakery product'],
#   '11-07-2015': ['domestic eggs']},
#  '1655': {'20-11-2015': ['whole milk'],
#   '04-11-2014': ['white wine', 'chocolate'],
#   '21-06-2014': ['frozen fish'],
#   '12-01-2014': ['rolls/buns']},
#  '1878': {'22-02-2015': ['yogurt'],
#   '17-10-2015': ['onions', 'misc. beverages'],
#   '10-01-2015': ['soda', 'candy'],
#   '07-09-2014': ['UHT-milk'],
#   '09-01-2014': ['liquor'],
#   '09-06-2014': ['canned beer'],
#   '02-01-2014': ['dessert'],
#   '22-08-2014': ['soda', 'soups']},
#  '3877': {'11-01-2015': ['whipped/sour cream'],
#   '27-05-2015': ['berries', 'chocolate'],
#   '27-06-2014': ['rolls/buns'],
#   '20-06-2014': ['cat food', 'zwieback', 'frozen dessert'],
#   '06-02-2014': ['soda', 'liquor (appetizer)'],
#   '17-09-2015': ['detergent']},
#  '3084': {'19-04-2015': ['salt'],
#   '10-08-2014': ['yogurt'],
#   '22-01-2014': ['other vegetables'],
#   '27-10-2014': ['white wine']},
#  '3160': {'22-01-2015': ['yogurt'],
#   '13-11-2014': ['yogurt'],
#   '14-01-2014': ['shopping bags']},
#  '1854': {'26-07-2015': ['newspapers'],
#   '11-03-2014': ['frozen fish'],
#   '30-09-2014': ['newspapers', 'soft cheese']},
#  '3195': {'30-01-2015': ['yogurt'], '08-07-2015': ['hygiene articles']},
#  '1170': {'01-12-2015': ['pip fruit'],
#   '12-11-2015': ['soda', 'bottled water', 'bottled water'],
#   '03-06-2014': ['shopping bags'],
#   '13-09-2014': ['whipped/sour cream'],
#   '22-05-2014': ['canned beer']},
#  '2653': {'07-12-2015': ['spread cheese'],
#   '17-04-2015': ['candy', 'chocolate'],
#   '21-04-2014': ['yogurt'],
#   '06-06-2014': ['dog food', 'newspapers']},
#  '2008': {'21-10-2015': ['soda'], '17-03-2014': ['soda']},
#  '3692': {'20-02-2015': ['coffee'],
#   '18-10-2015': ['packaged fruit/vegetables', 'yogurt'],
#   '19-10-2014': ['bottled beer'],
#   '09-01-2014': ['salty snack'],
#   '01-02-2014': ['frozen dessert', 'misc. beverages']},
#  '1016': {'23-04-2015': ['pip fruit'],
#   '30-09-2015': ['oil', 'pip fruit', 'mayonnaise'],
#   '19-07-2015': ['red/blush wine']},
#  '2015': {'12-05-2015': ['rum'], '04-08-2014': ['soda']},
#  '3002': {'19-02-2015': ['snack products'],
#   '22-01-2015': ['white bread', 'newspapers'],
#   '13-08-2015': ['coffee', 'seasonal products', 'yogurt', 'soups'],
#   '21-01-2015': ['grapes', 'light bulbs'],
#   '12-12-2014': ['hygiene articles', 'seasonal products']},
#  '4068': {'10-01-2015': ['yogurt'],
#   '11-12-2015': ['butter', 'specialty bar', 'detergent', 'specialty bar'],
#   '29-06-2014': ['canned beer']},
#  '4432': {'25-09-2015': ['coffee'],
#   '28-05-2015': ['female sanitary products'],
#   '04-12-2014': ['candy'],
#   '04-09-2014': ['salty snack'],
#   '01-09-2014': ['butter']},
#  '3406': {'17-05-2015': ['sliced cheese']},
#  '1844': {'10-02-2015': ['grapes'],
#   '24-07-2015': ['chewing gum', 'canned fruit'],
#   '18-09-2014': ['pastry'],
#   '27-04-2014': ['pastry'],
#   '10-04-2014': ['yogurt']},
#  ...}

# %% [markdown]
# ### Cell 7

# %%
item_length = 0

for i in item_dict:
    for j in item_dict[i]:
        item_length = item_length + len(item_dict[i][j])

print('Total items in the dictionary are:', item_length)
# Out:
# Total items in the dictionary are: 19415

# %% [markdown]
# ### Cell 8

# %%
transactions = list()
transactions_length = 0

for i in item_dict:
    for j in item_dict[i]:
        transactions.append(tuple(set(item_dict[i][j])))

for i in transactions:
    transactions_length = transactions_length + len(i)

print('Total items in the tuple accounting for duplicates are:', transactions_length)
# Out:
# Total items in the tuple accounting for duplicates are: 19250

# %% [markdown]
# ### Cell 9

# %%
maximum = (df_table['item_count'].loc[50])/transactions_length
minimum = 0
interval = (maximum - minimum)/10
minimum_support = list()

for i in range(9):
    minimum = minimum + interval
    minimum_support.append(round(minimum, 4))

minimum_support
# Out:
# [0.0005, 0.0011, 0.0016, 0.0022, 0.0027, 0.0032, 0.0038, 0.0043, 0.0049]

# %% [markdown]
# ### Cell 10

# %%
from efficient_apriori import apriori

support_dict = dict()
 
min_confidence = 0      # For now set min_confidence = 0 to obtain all the rules

for support in minimum_support:
    itemsets, rules = apriori(transactions, min_support=support, min_confidence=min_confidence)
    support_dict[support] = len(rules)

support_dict
# Out:
# {0.0005: 478,
#  0.0011: 94,
#  0.0016: 30,
#  0.0022: 14,
#  0.0027: 0,
#  0.0032: 0,
#  0.0038: 0,
#  0.0043: 0,
#  0.0049: 0}

# %% [markdown]
# ### Cell 11

# %%
from efficient_apriori import apriori

min_support = 0.0005
min_confidence = 0      # For now set min_confidence = 0 to obtain all the rules

itemsets, rules = apriori(transactions, min_support=min_support, min_confidence=min_confidence)

# %% [markdown]
# ### Cell 12

# %%
Rules = list()
Confidence = list()
Support = list()
Lift = list()
Conviction = list()

for rule in rules:
    rule = str(rule)

    Rules.append(rule[0:(rule.rfind('}')) + 1])
    Confidence.append(rule[(rule.index('conf: ')) + 5:(rule.index('conf: ')) + 11])
    Support.append(rule[(rule.index('supp: ')) + 5:(rule.index('supp: ')) + 11])
    Lift.append(rule[(rule.index('lift: ')) + 5:(rule.index('lift: ')) + 11])
    Conviction.append(rule[(rule.index('conv: ')) + 5:(rule.index('conv: ')) + 11])

df_rules = pd.DataFrame({'Rules':Rules, 'Confidence':Confidence, 'Support':Support, 'Lift':Lift, 'Conviction':Conviction})

df_rules
# Out:
#                                  Rules Confidence Support    Lift Conviction
# 0                {soda} -> {beverages}      0.009   0.001   1.155      1.001
# 1                {beverages} -> {soda}      0.077   0.001   1.155      1.011
# 2    {bottled water} -> {bottled beer}      0.015   0.001   0.536      0.987
# 3    {bottled beer} -> {bottled water}      0.023   0.001   0.536      0.980
# 4      {brown bread} -> {bottled beer}      0.027   0.001   0.980      0.999
# ..                                 ...        ...     ...     ...        ...
# 473      {white bread} -> {whole milk}      0.039   0.001   0.534      0.964
# 474          {yogurt} -> {white bread}      0.012   0.001   0.591      0.992
# 475          {white bread} -> {yogurt}      0.035   0.001   0.591      0.975
# 476           {yogurt} -> {whole milk}      0.030   0.002   0.408      0.955
# 477           {whole milk} -> {yogurt}      0.024   0.002   0.408      0.964
#
# [478 rows x 5 columns]

# %% [markdown]
# ### Cell 13

# %%
df_rules['Confidence'] = df_rules['Confidence'].astype(float) 
df_rules['Support'] = df_rules['Support'].astype(float) 
df_rules['Lift'] = df_rules['Lift'].astype(float) 
df_rules['Conviction'] = df_rules['Conviction'].astype(float) 
df_rules.dtypes
# Out:
# Rules          object
# Confidence    float64
# Support       float64
# Lift          float64
# Conviction    float64
# dtype: object

# %% [markdown]
# ### Cell 14

# %%
df_rules.drop(df_rules[df_rules['Lift'] <= 1].index, inplace=True) 
df_rules.drop(df_rules[df_rules['Conviction'] == 1].index, inplace=True) 
df_rules.describe()
# Out:
#        Confidence  Support      Lift  Conviction
# count   54.000000   54.000  54.00000   54.000000
# mean     0.036481    0.001   1.27013    1.007444
# std      0.022948    0.000   0.24342    0.007820
# min      0.007000    0.001   1.01500    1.001000
# 25%      0.018250    0.001   1.08350    1.002000
# 50%      0.030500    0.001   1.15500    1.004000
# 75%      0.052500    0.001   1.42850    1.010750
# max      0.090000    0.001   1.88300    1.033000

# %% [markdown]
# ### Cell 15

# %%
df_rules.sort_values(by=['Conviction', 'Lift', 'Confidence'], ascending=[False, False, False], inplace=True)
df_rules = df_rules.reset_index(drop=True)
df_rules = df_rules[0:15]
df_rules
# Out:
#                                       Rules  Confidence  Support   Lift  \
# 0                   {detergent} -> {yogurt}       0.090    0.001  1.501
# 1                 {soft cheese} -> {yogurt}       0.087    0.001  1.457
# 2     {cat food} -> {fruit/vegetable juice}       0.054    0.001  1.813
# 3             {chewing gum} -> {newspapers}       0.056    0.001  1.660
# 4                     {napkins} -> {pastry}       0.059    0.001  1.566
# 5   {long life bakery product} -> {napkins}       0.040    0.001  1.883
# 6                {sugar} -> {bottled water}       0.058    0.001  1.343
# 7   {napkins} -> {long life bakery product}       0.030    0.001  1.883
# 8                       {sugar} -> {coffee}       0.037    0.001  1.564
# 9                     {pastry} -> {napkins}       0.033    0.001  1.566
# 10                    {beverages} -> {soda}       0.077    0.001  1.155
# 11                          {oil} -> {soda}       0.076    0.001  1.147
# 12            {canned fish} -> {whole milk}       0.083    0.001  1.131
# 13    {semi-finished bread} -> {whole milk}       0.083    0.001  1.131
# 14         {chewing gum} -> {shopping bags}       0.056    0.001  1.197
#
#     Conviction
# 0        1.033
# 1        1.030
# 2        1.026
# 3        1.023
# 4        1.023
# 5        1.020
# 6        1.016
# 7        1.014
# 8        1.014
# 9        1.012
# 10       1.011
# 11       1.011
# 12       1.011
# 13       1.011
# 14       1.010

# %% [markdown]
# ### Cell 16

# %%
#Export association rules to .xlsx
df_rules.to_excel(f'Association_Rules.xlsx', index=False)

# %% [markdown]
# ### Cell 17

# %%
min_support = 0.0022
min_confidence = 0      # For now set min_confidence = 0 to obtain all the rules

itemsets, rules = apriori(transactions, min_support=min_support, min_confidence=min_confidence)

Rules = list()
Confidence = list()
Support = list()
Lift = list()
Conviction = list()

for rule in rules:
    rule = str(rule)

    Rules.append(rule[0:(rule.rfind('}')) + 1])
    Confidence.append(rule[(rule.index('conf: ')) + 5:(rule.index('conf: ')) + 11])
    Support.append(rule[(rule.index('supp: ')) + 5:(rule.index('supp: ')) + 11])
    Lift.append(rule[(rule.index('lift: ')) + 5:(rule.index('lift: ')) + 11])
    Conviction.append(rule[(rule.index('conv: ')) + 5:(rule.index('conv: ')) + 11])

df_rules = pd.DataFrame({'Rules':Rules, 'Confidence':Confidence, 'Support':Support, 'Lift':Lift, 'Conviction':Conviction})

df_rules['Confidence'] = df_rules['Confidence'].astype(float) 
df_rules['Support'] = df_rules['Support'].astype(float) 
df_rules['Lift'] = df_rules['Lift'].astype(float) 
df_rules['Conviction'] = df_rules['Conviction'].astype(float)

df_rules.sort_values(by=['Conviction', 'Lift', 'Confidence'], ascending=[False, False, False], inplace=True)
df_rules = df_rules.reset_index(drop=True)
df_rules = df_rules[0:15]
df_rules
# Out:
#                                  Rules  Confidence  Support   Lift  Conviction
# 0            {soda} -> {shopping bags}       0.035    0.002  0.761       0.988
# 1      {rolls/buns} -> {shopping bags}       0.033    0.002  0.710       0.986
# 2            {shopping bags} -> {soda}       0.051    0.002  0.761       0.983
# 3      {shopping bags} -> {rolls/buns}       0.049    0.002  0.710       0.979
# 4                   {soda} -> {yogurt}       0.039    0.003  0.647       0.978
# 5                   {yogurt} -> {soda}       0.043    0.003  0.647       0.975
# 6   {whole milk} -> {other vegetables}       0.033    0.002  0.562       0.973
# 7   {other vegetables} -> {whole milk}       0.041    0.002  0.562       0.966
# 8               {rolls/buns} -> {soda}       0.034    0.002  0.512       0.966
# 9               {whole milk} -> {soda}       0.034    0.003  0.511       0.966
# 10              {soda} -> {rolls/buns}       0.035    0.002  0.512       0.965
# 11        {whole milk} -> {rolls/buns}       0.035    0.003  0.509       0.965
# 12              {soda} -> {whole milk}       0.038    0.003  0.511       0.963
# 13        {rolls/buns} -> {whole milk}       0.037    0.003  0.509       0.962
